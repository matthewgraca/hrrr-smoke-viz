# %% [markdown]
# # Usage
# Ideally the only thing that needs to be changed is:
# - The start/end date of the data
# - The data ingestion portion
#
# The rest should be taken care of, assuming no bugs

# %% [markdown]
# # Data parameters

# %%
# define bounding box
lat_bottom, lat_top = 33.9, 34.2
lon_bottom, lon_top = -118.4, -118.0
extent = (lon_bottom, lon_top, lat_bottom, lat_top)

# input data shape
dim = 200
frames_per_sample = 5

# date range of data
start_date, end_date = "2024-12-01-00", "2025-01-31-23"

# %% [markdown]
# # Data ingestion and preprocessing

# %%
# python nonsense that allows you to import from sibling directories
import sys
sys.path.append("..")

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from dotenv import load_dotenv

# Import the data classes
from libs.pwwbdata import PWWBData
from libs.airnowdata import AirNowData
from libs.hrrrdata import HRRRData

# Load environment variables (API keys, credentials)
load_dotenv()

# split data
def train_test_split(X, train_size=0.75):
    split_idx = int(X.shape[0] * train_size)
    X_train, X_test = X[:split_idx], X[split_idx:]
    
    return X_train, X_test

# scale training data, then scale test data based on training data stats
from sklearn.preprocessing import StandardScaler
def std_scale(X_train, X_test):
    scaler = StandardScaler()
    scaled_train = scaler.fit_transform(X_train.reshape(-1, 1)).reshape(X_train.shape)
    scaled_test = scaler.transform(X_test.reshape(-1, 1)).reshape(X_test.shape)

    return scaled_train, scaled_test

# %%
# Create output directory for results
output_dir = "experiment_output"
os.makedirs(output_dir, exist_ok=True)

# ========== 1. Load PWWB Data ==========
print("\nLoading PWWB data...")
pwwb = PWWBData(
    start_date=start_date,
    end_date=end_date,
    extent=extent,
    frames_per_sample=frames_per_sample,
    dim=dim,
    env_file='.env',
    verbose=True,
    output_dir=output_dir
)
X_pwwb = pwwb.data
channel_info = pwwb.get_channel_info()
print(f"✓ PWWB data shape: {X_pwwb.shape}")
print(f"  Channels: {channel_info['channel_order']}")

# ========== 2. Load AirNow Data ==========
print("\nLoading AirNow data...")
airnow = AirNowData(
    start_date=start_date,
    end_date=end_date,
    extent=extent,
    airnow_api_key=os.getenv('AIRNOW_API_KEY'),
    frames_per_sample=frames_per_sample,
    dim=dim,
    elevation_path="../libs/inputs/elevation.npy",  # Path relative to current directory
    mask_path="../libs/inputs/mask.npy",  # Path relative to current directory
    force_reprocess=False
)
X_airnow = airnow.data
Y = airnow.target_stations
print(f"✓ AirNow data shape: {X_airnow.shape}")
if Y is not None:
    print(f"  Target stations shape: {Y.shape}")
else:
    print("  No target stations available")

# ========== 3. Load HRRR Data ==========
print("\nLoading HRRR data...")
hrrr = HRRRData(
    start_date=start_date,
    end_date=end_date,
    extent=extent,
    extent_name='la_region',
    product='MASSDEN',
    frames_per_sample=frames_per_sample,
    dim=dim,
    verbose=True
)
# Convert units from kg to micrograms (1e9)
ug_per_kg = 1000000000
X_hrrr = hrrr.data * ug_per_kg
print(f"✓ HRRR data shape: {X_hrrr.shape}")
# Out:
# Loading PWWB data...
# Initialized PWWBData with 1488 hourly timestamps
# Date range: 2024-12-01 00:00:00 to 2025-01-31 23:00:00
# Note: Following pattern in pm25Script_noGCN.py, MAIAC data will use a single observation from start date (2024-12-01)
# Processing Landsat data...
# Loading cached Landsat data from data/pwwb_cache/landsat_data.npy
# Processing MAIAC AOD data (from start date only)...
# Loading cached MAIAC data from data/pwwb_cache/maiac_data.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Visualization saved to 'experiment_output/combined_channels_visualization.png'
# Final data shape: (1461, 5, 200, 200, 4)
#
# Data Statistics:
# ===============
#
# MAIAC Data:
#   Day 0 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 1 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 2 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 3 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 4 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 5 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 6 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 7 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 8 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#   Day 9 stats:
#     Min: 0.00000
#     Max: 0.08825
#     Mean: 0.00001
#     Data coverage: 0.01%
#
# Landsat Data:
#   Band 0 stats:
#     Min: 0.0
#     Max: 22910.0
#     Mean: 866.9083
#     Data coverage: 10.53%
#   Band 1 stats:
#     Min: 0.0
#     Max: 27443.0
#     Mean: 1061.295375
#     Data coverage: 10.53%
#   Band 2 stats:
#     Min: 1.0
#     Max: 228.0
#     Mean: 12.2359
#     Data coverage: 100.00%
#
# Final Data Shape:
#   1461 samples
#   5 frames per sample
#   200x200 grid size
#   4 channels
# ✓ PWWB data shape: (1461, 5, 200, 200, 4)
#   Channels: ['Landsat_SR_B1', 'Landsat_SR_B7', 'Landsat_QA_AEROSOL', 'MAIAC_AOD']
#
# Loading AirNow data...
# Using mask from ../libs/inputs/mask.npy
# Loading processed AirNow data from cache: data/airnow_processed.npz
# ✓ Successfully loaded processed data from cache
#   - Data shape: (1461, 5, 200, 200, 1)
#   - Found 3 sensor locations
# ✓ AirNow data shape: (1461, 5, 200, 200, 1)
#   Target stations shape: (1461, 3)
#
# Loading HRRR data...
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-01 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-02 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-03 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-04 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-05 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-06 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-07 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-08 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-09 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-10 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-11 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-12 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-13 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-14 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-15 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-16 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-17 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-18 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-19 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-20 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-21 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 15:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 16:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 17:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 18:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 19:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 20:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 21:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 22:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-22 23:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 00:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 01:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 02:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 03:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 04:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 05:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 06:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 07:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 08:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 09:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 10:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 11:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 12:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 13:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 14:00 UTC F00 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2024-Dec-23 15:00 UTC F00 ┊ source=aws
# ...
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_b3ef9dd4__hrrr.t02z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_5cef9dd4__hrrr.t03z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_b6ef9dd4__hrrr.t04z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_c8ef9dd4__hrrr.t05z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_4eef9dd4__hrrr.t06z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_eeef9dd4__hrrr.t07z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_16ef9dd4__hrrr.t08z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_2bef9dd4__hrrr.t09z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_fcef9dd4__hrrr.t10z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_9def9dd4__hrrr.t11z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_26ef9dd4__hrrr.t12z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_51ef9dd4__hrrr.t13z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_5eef9dd4__hrrr.t14z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_52ef9dd4__hrrr.t15z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_d2ef9dd4__hrrr.t16z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_39ef9dd4__hrrr.t17z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_80ef9dd4__hrrr.t18z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_7eef9dd4__hrrr.t19z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_d5ef9dd4__hrrr.t20z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_0fef9dd4__hrrr.t21z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_afef9dd4__hrrr.t22z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250127/la_region_subset_1bef9dd4__hrrr.t23z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_92ef9dd4__hrrr.t00z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_2eef9dd4__hrrr.t01z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_b5ef9dd4__hrrr.t02z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_9cef9dd4__hrrr.t03z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_4cef9dd4__hrrr.t04z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_8fef9dd4__hrrr.t05z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_98ef9dd4__hrrr.t06z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_58ef9dd4__hrrr.t07z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_7fef9dd4__hrrr.t08z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_cdef9dd4__hrrr.t09z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_10ef9dd4__hrrr.t10z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_46ef9dd4__hrrr.t11z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_90ef9dd4__hrrr.t12z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_9cef9dd4__hrrr.t13z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_89ef9dd4__hrrr.t14z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_a7ef9dd4__hrrr.t15z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_29ef9dd4__hrrr.t16z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_34ef9dd4__hrrr.t17z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_3cef9dd4__hrrr.t18z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_45ef9dd4__hrrr.t19z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_0fef9dd4__hrrr.t20z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_0bef9dd4__hrrr.t21z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_05ef9dd4__hrrr.t22z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250128/la_region_subset_15ef9dd4__hrrr.t23z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_1cef9dd4__hrrr.t00z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_12ef9dd4__hrrr.t01z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_c5ef9dd4__hrrr.t02z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_91ef9dd4__hrrr.t03z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_c4ef9dd4__hrrr.t04z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_4bef9dd4__hrrr.t05z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_7fef9dd4__hrrr.t06z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_0aef9dd4__hrrr.t07z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_75ef9dd4__hrrr.t08z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_ffef9dd4__hrrr.t09z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_b0ef9dd4__hrrr.t10z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_79ef9dd4__hrrr.t11z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_39ef9dd4__hrrr.t12z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_b3ef9dd4__hrrr.t13z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_beef9dd4__hrrr.t14z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_94ef9dd4__hrrr.t15z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_40ef9dd4__hrrr.t16z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_78ef9dd4__hrrr.t17z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_9bef9dd4__hrrr.t18z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_ffef9dd4__hrrr.t19z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_27ef9dd4__hrrr.t20z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_9fef9dd4__hrrr.t21z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_cfef9dd4__hrrr.t22z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250129/la_region_subset_30ef9dd4__hrrr.t23z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_08ef9dd4__hrrr.t00z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_66ef9dd4__hrrr.t01z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_3aef9dd4__hrrr.t02z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_74ef9dd4__hrrr.t03z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_98ef9dd4__hrrr.t04z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_c9ef9dd4__hrrr.t05z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_0cef9dd4__hrrr.t06z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_2cef9dd4__hrrr.t07z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_58ef9dd4__hrrr.t08z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_48ef9dd4__hrrr.t09z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_9aef9dd4__hrrr.t10z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_faef9dd4__hrrr.t11z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_24ef9dd4__hrrr.t12z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_7cef9dd4__hrrr.t13z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_0eef9dd4__hrrr.t14z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_b4ef9dd4__hrrr.t15z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_66ef9dd4__hrrr.t16z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_0bef9dd4__hrrr.t17z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_86ef9dd4__hrrr.t18z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_d9ef9dd4__hrrr.t19z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_7eef9dd4__hrrr.t20z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_68ef9dd4__hrrr.t21z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_dcef9dd4__hrrr.t22z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250130/la_region_subset_ecef9dd4__hrrr.t23z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_7fef9dd4__hrrr.t00z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_b9ef9dd4__hrrr.t01z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_82ef9dd4__hrrr.t02z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_69ef9dd4__hrrr.t03z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_39ef9dd4__hrrr.t04z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_7def9dd4__hrrr.t05z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_8bef9dd4__hrrr.t06z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_fdef9dd4__hrrr.t07z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_15ef9dd4__hrrr.t08z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_d5ef9dd4__hrrr.t09z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_bbef9dd4__hrrr.t10z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_d1ef9dd4__hrrr.t11z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_9fef9dd4__hrrr.t12z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_1bef9dd4__hrrr.t13z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_41ef9dd4__hrrr.t14z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_6cef9dd4__hrrr.t15z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_1eef9dd4__hrrr.t16z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_f0ef9dd4__hrrr.t17z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_98ef9dd4__hrrr.t18z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_f9ef9dd4__hrrr.t19z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_83ef9dd4__hrrr.t20z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_06ef9dd4__hrrr.t21z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_b6ef9dd4__hrrr.t22z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/moh/data/hrrr/20250131/la_region_subset_eeef9dd4__hrrr.t23z.wrfsfcf00.grib2.5b7b6.idx' older than GRIB file
# ✓ HRRR data shape: (1484, 5, 200, 200, 1)

# %%
# ========== 4. Split into December (no fire) and January (fire) sets ========== (Thwere's a bug here we need to fix)

# Splitting data into December and January sets...
#   December PWWB frames: (721, 5, 200, 200, 4)
#   January PWWB frames: (740, 5, 200, 200, 4)
#   December AirNow frames: (721, 5, 200, 200, 1)
#   January AirNow frames: (740, 5, 200, 200, 1)
#   December HRRR frames: (721, 5, 200, 200, 1)
#   January HRRR frames: (740, 5, 200, 200, 1)
#   December target data: (721, 3)
#   January target data: (740, 3)
# These should be equal in both january and december shouldn't they? december has 721, jaunary has 740?
print("\nSplitting data into December and January sets...")
december_end = "2024-12-31"
december_end_dt = pd.to_datetime(december_end)

# Function to split data by month
def split_monthly(data, start_date, end_date, dec_end_date):
    # Create hourly timestamps from start to end
    full_timestamps = pd.date_range(start_date, end_date, freq='H')
    
    # Find December indices (timestamps up to and including dec_end_date)
    december_indices = np.where(full_timestamps <= pd.to_datetime(dec_end_date))[0]
    
    # Split the data
    if len(december_indices) == 0:
        return None, data  # All January data
    elif len(december_indices) == len(full_timestamps):
        return data, None  # All December data
    
    december_end_idx = december_indices[-1] + 1  # +1 to include the last hour
    
    # Split the data
    december_frames = data[:december_end_idx]
    january_frames = data[december_end_idx:]
    
    return december_frames, january_frames

# Split PWWB data
pwwb_december, pwwb_january = split_monthly(X_pwwb, start_date, end_date, december_end)
print(f"  December PWWB frames: {pwwb_december.shape}")
print(f"  January PWWB frames: {pwwb_january.shape}")

# Split AirNow data
airnow_december, airnow_january = split_monthly(X_airnow, start_date, end_date, december_end)
print(f"  December AirNow frames: {airnow_december.shape}")
print(f"  January AirNow frames: {airnow_january.shape}")

# Split HRRR data
hrrr_december, hrrr_january = split_monthly(X_hrrr, start_date, end_date, december_end)
print(f"  December HRRR frames: {hrrr_december.shape}")
print(f"  January HRRR frames: {hrrr_january.shape}")

# Split target data
if Y is not None:
    Y_december, Y_january = split_monthly(Y, start_date, end_date, december_end)
    print(f"  December target data: {Y_december.shape if Y_december is not None else 'None'}")
    print(f"  January target data: {Y_january.shape if Y_january is not None else 'None'}")
# Out:
# Aligning dataset lengths...
#   Original shapes: PWWB=(1461, 5, 200, 200, 4), AirNow=(1461, 5, 200, 200, 1), HRRR=(1461, 5, 200, 200, 1)
#   Aligned shapes: PWWB=(1461, 5, 200, 200, 4), AirNow=(1461, 5, 200, 200, 1), HRRR=(1461, 5, 200, 200, 1)
#   Target shape: (1461, 3)
#
# Splitting data into December and January sets...
#   December PWWB frames: (721, 5, 200, 200, 4)
#   January PWWB frames: (740, 5, 200, 200, 4)
#   December AirNow frames: (721, 5, 200, 200, 1)
#   January AirNow frames: (740, 5, 200, 200, 1)
#   December HRRR frames: (721, 5, 200, 200, 1)
#   January HRRR frames: (740, 5, 200, 200, 1)
#   December target data: (721, 3)
#   January target data: (740, 3)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# ========== 5. Create the four experiment datasets ==========
print("\nCreating the four experiment datasets...")

# Experiment 1: No-fire December set (PWWB + AirNow)
print("  Experiment 1: No-fire December set (PWWB + AirNow)")
X_exp1 = np.concatenate([pwwb_december, airnow_december], axis=-1)
print(f"    Combined shape: {X_exp1.shape}")

# Experiment 2: No-fire December set + HRRR
print("  Experiment 2: No-fire December set + HRRR")
X_exp2 = np.concatenate([pwwb_december, airnow_december, hrrr_december], axis=-1)
print(f"    Combined shape: {X_exp2.shape}")

# Experiment 3: Fire January set (PWWB + AirNow)
print("  Experiment 3: Fire January set (PWWB + AirNow)")
X_exp3 = np.concatenate([pwwb_january, airnow_january], axis=-1)
print(f"    Combined shape: {X_exp3.shape}")

# Experiment 4: Fire January set + HRRR
print("  Experiment 4: Fire January set + HRRR")
X_exp4 = np.concatenate([pwwb_january, airnow_january, hrrr_january], axis=-1)
print(f"    Combined shape: {X_exp4.shape}")
# Out:
# Creating the four experiment datasets...
#   Experiment 1: No-fire December set (PWWB + AirNow)
#     Combined shape: (721, 5, 200, 200, 5)
#   Experiment 2: No-fire December set + HRRR

# %%
# ========== 6. Train/Test Split for each experiment ==========
print("\nCreating train/test splits for each experiment...")

# Experiment 1 splits
X_exp1_train, X_exp1_test = train_test_split(X_exp1, train_size=0.75)
Y_december_train, Y_december_test = train_test_split(Y_december, train_size=0.75)
print(f"  Experiment 1: Train={X_exp1_train.shape}, Test={X_exp1_test.shape}")

# Experiment 2 splits
X_exp2_train, X_exp2_test = train_test_split(X_exp2, train_size=0.75)
print(f"  Experiment 2: Train={X_exp2_train.shape}, Test={X_exp2_test.shape}")

# Experiment 3 splits
X_exp3_train, X_exp3_test = train_test_split(X_exp3, train_size=0.75)
Y_january_train, Y_january_test = train_test_split(Y_january, train_size=0.75)
print(f"  Experiment 3: Train={X_exp3_train.shape}, Test={X_exp3_test.shape}")

# Experiment 4 splits
X_exp4_train, X_exp4_test = train_test_split(X_exp4, train_size=0.75)
print(f"  Experiment 4: Train={X_exp4_train.shape}, Test={X_exp4_test.shape}")

# ========== 7. Standardize data for each experiment ==========
print("\nStandardizing data for each experiment...")

# Experiment 1 standardization
X_exp1_train_scaled, X_exp1_test_scaled = std_scale(X_exp1_train, X_exp1_test)
print(f"  Experiment 1: Scaled train={X_exp1_train_scaled.shape}, test={X_exp1_test_scaled.shape}")

# Experiment 2 standardization
X_exp2_train_scaled, X_exp2_test_scaled = std_scale(X_exp2_train, X_exp2_test)
print(f"  Experiment 2: Scaled train={X_exp2_train_scaled.shape}, test={X_exp2_test_scaled.shape}")

# Experiment 3 standardization
X_exp3_train_scaled, X_exp3_test_scaled = std_scale(X_exp3_train, X_exp3_test)
print(f"  Experiment 3: Scaled train={X_exp3_train_scaled.shape}, test={X_exp3_test_scaled.shape}")

# Experiment 4 standardization
X_exp4_train_scaled, X_exp4_test_scaled = std_scale(X_exp4_train, X_exp4_test)
print(f"  Experiment 4: Scaled train={X_exp4_train_scaled.shape}, test={X_exp4_test_scaled.shape}")

# %%
# ========== 8. Save prepared datasets ==========
print("\nSaving prepared datasets...")

# Create directories for each experiment
exp_dirs = {}
for i in range(1, 5):
    exp_dir = os.path.join(output_dir, f"experiment{i}")
    os.makedirs(exp_dir, exist_ok=True)
    exp_dirs[i] = exp_dir

# Save Experiment 1 data
np.save(os.path.join(exp_dirs[1], "X_train.npy"), X_exp1_train_scaled)
np.save(os.path.join(exp_dirs[1], "X_test.npy"), X_exp1_test_scaled)
np.save(os.path.join(exp_dirs[1], "y_train.npy"), Y_december_train)
np.save(os.path.join(exp_dirs[1], "y_test.npy"), Y_december_test)

# Save Experiment 2 data
np.save(os.path.join(exp_dirs[2], "X_train.npy"), X_exp2_train_scaled)
np.save(os.path.join(exp_dirs[2], "X_test.npy"), X_exp2_test_scaled)
np.save(os.path.join(exp_dirs[2], "y_train.npy"), Y_december_train)
np.save(os.path.join(exp_dirs[2], "y_test.npy"), Y_december_test)

# Save Experiment 3 data
np.save(os.path.join(exp_dirs[3], "X_train.npy"), X_exp3_train_scaled)
np.save(os.path.join(exp_dirs[3], "X_test.npy"), X_exp3_test_scaled)
np.save(os.path.join(exp_dirs[3], "y_train.npy"), Y_january_train)
np.save(os.path.join(exp_dirs[3], "y_test.npy"), Y_january_test)

# Save Experiment 4 data
np.save(os.path.join(exp_dirs[4], "X_train.npy"), X_exp4_train_scaled)
np.save(os.path.join(exp_dirs[4], "X_test.npy"), X_exp4_test_scaled)
np.save(os.path.join(exp_dirs[4], "y_train.npy"), Y_january_train)
np.save(os.path.join(exp_dirs[4], "y_test.npy"), Y_january_test)

print("\n✓ All datasets prepared and saved!")
print("Ready to run experiments 1-4")

# %% [markdown]
# # Data visualization

# %%
# Function to visualize data from any experiment
def visualize_experiment_data(X, y, exp_number, sample_idx=None):
    """Visualize data from a specific experiment"""
    # Get a random sample if none provided
    if sample_idx is None:
        np.random.seed(42)
        sample_idx = np.random.choice(range(len(X)), size=1)[0]
    
    # Get channel information
    n_channels = X.shape[4]
    n_frames = X.shape[1]
    
    # Create figure
    fig, axes = plt.subplots(n_channels, n_frames, figsize=(3*n_frames, 2*n_channels))
    if n_channels == 1:
        axes = axes.reshape(1, -1)
    
    # Plot each channel and frame
    for c in range(n_channels):
        for f in range(n_frames):
            ax = axes[c, f]
            ax.imshow(X[sample_idx, f, :, :, c])
            if f == 0:
                ax.set_ylabel(f"Channel {c}")
            ax.set_title(f"Frame {f+1}")
            ax.axis("off")
    
    # Set title
    exp_descriptions = {
        1: "No-fire December set (PWWB + AirNow)",
        2: "No-fire December set + HRRR",
        3: "Fire January set (PWWB + AirNow)",
        4: "Fire January set + HRRR"
    }
    plt.suptitle(f"Experiment {exp_number}: {exp_descriptions[exp_number]}\nSample {sample_idx}")
    plt.tight_layout()
    plt.show()
    
    # Print target values
    print(f"Target values: {y[sample_idx]}")

# Visualize a sample from each experiment
print("Visualizing data from all experiments...")
visualize_experiment_data(X_exp1_train_scaled, Y_december_train, 1)
visualize_experiment_data(X_exp2_train_scaled, Y_december_train, 2)
visualize_experiment_data(X_exp3_train_scaled, Y_january_train, 3)
visualize_experiment_data(X_exp4_train_scaled, Y_january_train, 4)

# %% [markdown]
# # Model

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv3D
from keras.layers import ConvLSTM2D
from keras.layers import BatchNormalization
from keras.layers import Convolution2D, MaxPooling3D, Flatten, Reshape
from keras.layers import TimeDistributed
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import InputLayer

tf.keras.backend.set_image_data_format('channels_last')

# Function to run a single experiment
def run_experiment(exp_number, epochs=150, batch_size=4):
    """Train and evaluate a model for a specific experiment"""
    # Set up experiment data
    if exp_number == 1:
        X_train = X_exp1_train_scaled
        y_train = Y_december_train
        X_test = X_exp1_test_scaled
        y_test = Y_december_test
        description = "No-fire December set (PWWB + AirNow)"
    elif exp_number == 2:
        X_train = X_exp2_train_scaled
        y_train = Y_december_train
        X_test = X_exp2_test_scaled
        y_test = Y_december_test
        description = "No-fire December set + HRRR"
    elif exp_number == 3:
        X_train = X_exp3_train_scaled
        y_train = Y_january_train
        X_test = X_exp3_test_scaled
        y_test = Y_january_test
        description = "Fire January set (PWWB + AirNow)"
    elif exp_number == 4:
        X_train = X_exp4_train_scaled
        y_train = Y_january_train
        X_test = X_exp4_test_scaled
        y_test = Y_january_test
        description = "Fire January set + HRRR"
    else:
        print(f"Invalid experiment number: {exp_number}")
        return None
    
    print(f"\n==== Running Experiment {exp_number}: {description} ====")
    print(f"Training data shape: {X_train.shape}")
    print(f"Target data shape: {y_train.shape}")
    
    # Build model
    seq = Sequential()
    
    seq.add(
        InputLayer(shape=X_train.shape[1:])
    )
    
    seq.add(
        ConvLSTM2D(
                filters=15, 
                kernel_size=(3, 3),
                padding='same', 
                return_sequences=True
        )
    )
    
    seq.add(
        ConvLSTM2D(
            filters=30, 
            kernel_size=(3, 3),
            padding='same', 
            return_sequences=True
        )
    )
    
    seq.add(
        Conv3D(
            filters=15, 
            kernel_size=(3, 3, 3),
            activation='relu',
            padding='same'    
        )
    )
    
    seq.add(
        Conv3D(
            filters=1, 
            kernel_size=(3, 3, 3),
            activation='relu',
            padding='same'
        )
    )
    
    seq.add(Flatten())
    seq.add(Dense(y_train.shape[1], activation='relu'))
    
    # Compile model
    seq.compile(loss='mean_absolute_error', optimizer='adam')
    
    # Print model summary
    seq.summary()
    
    # Train model
    print(f"\nTraining model for experiment {exp_number}...")
    history = seq.fit(
        X_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=0.2
    )
    
    # Evaluate model
    print(f"\nEvaluating model for experiment {exp_number}...")
    test_loss = seq.evaluate(X_test, y_test, verbose=0)
    print(f"Test MAE: {test_loss:.4f}")
    
    # Make predictions
    y_pred = seq.predict(X_test, verbose=0)
    
    # Calculate metrics
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
    
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    print(f"Mean Absolute Error: {mae:.4f}")
    print(f"Root Mean Squared Error: {rmse:.4f}")
    print(f"R² Score: {r2:.4f}")
    
    # Plot training history
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.legend()
    plt.title(f'Experiment {exp_number}: {description}\nTraining Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss (MAE)')
    plt.grid(True, alpha=0.3)
    plt.show()
    
    # Save results
    results_dir = os.path.join(output_dir, f"experiment{exp_number}", "results")
    os.makedirs(results_dir, exist_ok=True)
    
    np.save(os.path.join(results_dir, "y_pred.npy"), y_pred)
    seq.save(os.path.join(results_dir, "model.h5"))
    
    return {
        'model': seq,
        'history': history,
        'loss': test_loss,
        'mae': mae,
        'rmse': rmse,
        'r2': r2,
        'y_pred': y_pred,
        'y_test': y_test
    }

# %%
# Run Experiment 1: No-fire December set (PWWB + AirNow)
exp1_results = run_experiment(1, epochs=50)  # Reduced epochs for faster testing

# %%
# Run Experiment 2: No-fire December set + HRRR
exp2_results = run_experiment(2, epochs=50)

# %%
# Run Experiment 3: Fire January set (PWWB + AirNow)
exp3_results = run_experiment(3, epochs=50)

# %%
# Run Experiment 4: Fire January set + HRRR
exp4_results = run_experiment(4, epochs=50)

# %% [markdown]
# # Evaluate

# %%
# Compare results across all experiments
print("\n==== Experiment Comparison ====")
print(f"Experiment 1 (No-fire December): MAE = {exp1_results['mae']:.4f}")
print(f"Experiment 2 (No-fire December + HRRR): MAE = {exp2_results['mae']:.4f}")
print(f"Experiment 3 (Fire January): MAE = {exp3_results['mae']:.4f}")
print(f"Experiment 4 (Fire January + HRRR): MAE = {exp4_results['mae']:.4f}")

# Visualize comparison
experiments = ['Exp 1\nDec', 'Exp 2\nDec+HRRR', 'Exp 3\nJan', 'Exp 4\nJan+HRRR']
maes = [exp1_results['mae'], exp2_results['mae'], exp3_results['mae'], exp4_results['mae']]
rmses = [exp1_results['rmse'], exp2_results['rmse'], exp3_results['rmse'], exp4_results['rmse']]

plt.figure(figsize=(12, 6))

# Plot MAEs
plt.subplot(1, 2, 1)
plt.bar(experiments, maes, color=['blue', 'skyblue', 'red', 'salmon'])
plt.title('MAE Comparison')
plt.ylabel('Mean Absolute Error')
plt.grid(True, alpha=0.3, axis='y')
for i, v in enumerate(maes):
    plt.text(i, v + 0.01, f'{v:.4f}', ha='center')

# Plot RMSEs
plt.subplot(1, 2, 2)
plt.bar(experiments, rmses, color=['blue', 'skyblue', 'red', 'salmon'])
plt.title('RMSE Comparison')
plt.ylabel('Root Mean Squared Error')
plt.grid(True, alpha=0.3, axis='y')
for i, v in enumerate(rmses):
    plt.text(i, v + 0.01, f'{v:.4f}', ha='center')

plt.suptitle('Performance Comparison Across Experiments')
plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'experiment_comparison.png'))
plt.show()

# Save comparison results
with open(os.path.join(output_dir, 'experiment_comparison.txt'), 'w') as f:
    f.write("==== Experiment Comparison ====\n")
    f.write(f"Experiment 1 (No-fire December): MAE = {exp1_results['mae']:.4f}, RMSE = {exp1_results['rmse']:.4f}, R² = {exp1_results['r2']:.4f}\n")
    f.write(f"Experiment 2 (No-fire December + HRRR): MAE = {exp2_results['mae']:.4f}, RMSE = {exp2_results['rmse']:.4f}, R² = {exp2_results['r2']:.4f}\n")
    f.write(f"Experiment 3 (Fire January): MAE = {exp3_results['mae']:.4f}, RMSE = {exp3_results['rmse']:.4f}, R² = {exp3_results['r2']:.4f}\n")
    f.write(f"Experiment 4 (Fire January + HRRR): MAE = {exp4_results['mae']:.4f}, RMSE = {exp4_results['rmse']:.4f}, R² = {exp4_results['r2']:.4f}\n")
    f.write(f"\nAnalysis completed on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

print("\nExperiment comparison complete!")

# %%
# For detailed analysis of a specific experiment (e.g., Experiment 1)
# Choose which experiment to analyze
selected_exp = 1  # Change this to analyze a different experiment (1-4)

# Set the appropriate data and results
if selected_exp == 1:
    X_test = X_exp1_test_scaled
    y_test = Y_december_test
    y_pred = exp1_results['y_pred']
    model = exp1_results['model']
    description = "No-fire December set (PWWB + AirNow)"
elif selected_exp == 2:
    X_test = X_exp2_test_scaled
    y_test = Y_december_test
    y_pred = exp2_results['y_pred']
    model = exp2_results['model']
    description = "No-fire December set + HRRR"
elif selected_exp == 3:
    X_test = X_exp3_test_scaled
    y_test = Y_january_test
    y_pred = exp3_results['y_pred']
    model = exp3_results['model']
    description = "Fire January set (PWWB + AirNow)"
elif selected_exp == 4:
    X_test = X_exp4_test_scaled
    y_test = Y_january_test
    y_pred = exp4_results['y_pred']
    model = exp4_results['model']
    description = "Fire January set + HRRR"
else:
    print(f"Invalid experiment number: {selected_exp}")

print(f"Analyzing Experiment {selected_exp}: {description}")

# %%
from libs.plotting import (
    plot_prediction_comparison,
    plot_scatter_comparison,
    plot_error_by_sensor,
    plot_time_series_comparison,
    plot_input_frames,
    print_metrics
)

# Sensor names (use AirNow sensor names if available)
if hasattr(airnow, 'sensor_names') and airnow.sensor_names is not None:
    sensor_names = airnow.sensor_names
else:
    sensor_names = ["North Hollywood", "Los Angeles - N. Main Street", "Compton"]

print(f"\nDetailed analysis for Experiment {selected_exp}:")
print("\n1. Plotting prediction comparison...")
plot_prediction_comparison(y_pred, y_test, sensor_names, sample_idx=12)

print("\n2. Plotting scatter comparison...")
plot_scatter_comparison(y_pred, y_test)

print("\n3. Plotting error by sensor...")
plot_error_by_sensor(y_pred, y_test, sensor_names)

print("\n4. Plotting time series comparison...")
plot_time_series_comparison(y_pred, y_test, sensor_names)
    
print("\n5. Plotting time series with shifted predictions...")
plot_time_series_comparison(y_pred, y_test, sensor_names, shift_pred=1)

print("\n6. Printing metrics...")
print_metrics(y_pred, y_test, sensor_names)
