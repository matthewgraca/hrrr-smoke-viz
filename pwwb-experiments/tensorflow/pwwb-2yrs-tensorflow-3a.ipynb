# %% [markdown]
# # Air Quality Prediction Experiment
#
# This notebook combines PWWB, AirNow, and HRRR datasets for air quality prediction using TF-Keras.
# Changes:
# - A lot of hard coding things like sensor names
# - Have another script handle ALL preprocessing; we just load the numpy files and stack them here
# - Removed scaled target data for simplicity
#
# Differences from original test:
# - Last notebook had overfitting issue; adding dropout rate of 50%.
# - Epochs 150 -> 100. Will increase if loss is trending well.
# - Reduced target sensors that were in the periphery outside of the LA metropolitan area
# - Added HRRR data

# %% [markdown]
# # Load data

# %%
# ========== EXPERIMENT CONFIGURATION ==========
# Change these variables to configure your experiment
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import os
from datetime import datetime

EXPERIMENT_NAME = "January 2022 to December 2024"
EXPERIMENT_DESCRIPTION = "January 2025 fire period with PWWB, Airnow, and HRRR data."
EXPERIMENT_ID = "two_years_pwwb_airnow_hrrr"

# Data parameters
START_DATE = "2022-12-01-00"
END_DATE = "2024-12-01-00"
TRAIN_SPLIT = 0.80  # 70% for training, 10% for val (will split later), leaving 20% for test.

# Model parameters
EPOCHS = 100
BATCH_SIZE = 16
WEIGHT_DECAY = 0.01

all_channel_names = ['MAIAC_AOD', 'TROPOMI_NO2', 'METAR_Wind_U', 'METAR_Wind_V', 'AirNow_PM25', 'HRRR_COLMD']

print(f"Experiment: {EXPERIMENT_NAME}")
print(f"Description: {EXPERIMENT_DESCRIPTION}")
print(f"Date Range: {START_DATE} to {END_DATE}")
print(f"Train/Test Split: {TRAIN_SPLIT*100:.0f}%/{(1-TRAIN_SPLIT)*100:.0f}% (temporal)")
# Out:
# Experiment: January 2022 to December 2024
# Description: January 2025 fire period with PWWB, Airnow, and HRRR data.
# Date Range: 2022-12-01-00 to 2024-12-01-00
# Train/Test Split: 80%/20% (temporal)

# %%
# load: X_train_scaled, X_test_scaled (combined from np files), y_train, y_test.
test_files = [
    "MAIAC_AOD_X_test.npy", "TROPOMI_NO2_X_test.npy", 
    "METAR_Wind_U_X_test.npy", "METAR_Wind_V_X_test.npy", 
    "AirNow_PM25_X_test.npy", "HRRR_COLMD_X_test.npy"
]
train_files = [
    "MAIAC_AOD_X_train.npy", "TROPOMI_NO2_X_train.npy", 
    "METAR_Wind_U_X_train.npy", "METAR_Wind_V_X_train.npy", 
    "AirNow_PM25_X_train.npy", "HRRR_COLMD_X_train.npy"
]
X_train_scaled = np.stack([np.load(f"final_input_data/{file}") for file in train_files], axis=-1)
X_test_scaled = np.stack([np.load(f"final_input_data/{file}") for file in test_files], axis=-1)
Y_train = np.load("final_input_data/Y_train.npy")
Y_test = np.load("final_input_data/Y_test.npy")

# %%
# Debug cell to check channel names and data shapes
print("=== DEBUGGING CHANNEL INFORMATION ===")
print(f"Experiment name: {EXPERIMENT_NAME}")
print(f"X_train_scaled shape: {X_train_scaled.shape}")
print(f"Number of channels in data: {X_train_scaled.shape[4]}")
print(f"Number of channel names provided: {len(all_channel_names)}")
print(f"Channel names length matches data channels: {len(all_channel_names) == X_train_scaled.shape[4]}")
print()

print("Channel names provided:")
for i, name in enumerate(all_channel_names):
    print(f"  {i}: {name}")
print()

print("What the visualization function will use:")
n_channels = X_train_scaled.shape[4]
if all_channel_names is None or len(all_channel_names) != n_channels:
    effective_channel_names = [f"Channel {i}" for i in range(n_channels)]
    print("  Using GENERIC channel names (this is the problem!):")
else:
    effective_channel_names = all_channel_names
    print("  Using PROVIDED channel names:")

for i, name in enumerate(effective_channel_names):
    print(f"  {i}: {name}")
print()

print("=== DATA SAMPLE CHECK ===")
# Check what's actually in the first few channels
sample_idx = 42  # Use same sample as visualization
for c in range(min(3, n_channels)):  # Check first 3 channels
    data = X_train_scaled[sample_idx, 0, :, :, c]  # First frame
    print(f"Channel {c} ({effective_channel_names[c] if c < len(effective_channel_names) else 'Unknown'}):")
    print(f"  Min: {data.min():.6f}, Max: {data.max():.6f}, Mean: {data.mean():.6f}")
    print()
# Out:
# === DEBUGGING CHANNEL INFORMATION ===
# Experiment name: January 2022 to December 2024
# X_train_scaled shape: (13958, 5, 40, 40, 6)
# Number of channels in data: 6
# Number of channel names provided: 6
# Channel names length matches data channels: True
#
# Channel names provided:
#   0: MAIAC_AOD
#   1: TROPOMI_NO2
#   2: METAR_Wind_U
#   3: METAR_Wind_V
#   4: AirNow_PM25
#   5: HRRR_COLMD
#
# What the visualization function will use:
#   Using PROVIDED channel names:
#   0: MAIAC_AOD
#   1: TROPOMI_NO2
#   2: METAR_Wind_U
#   3: METAR_Wind_V
#   4: AirNow_PM25
#   5: HRRR_COLMD
#
# === DATA SAMPLE CHECK ===
# Channel 0 (MAIAC_AOD):
#   Min: -1.079774, Max: 1.541646, Mean: -0.266231
#
# Channel 1 (TROPOMI_NO2):
#   Min: -0.565192, Max: 0.132405, Mean: -0.141304
#
# Channel 2 (METAR_Wind_U):
#   Min: -2.469496, Max: -2.209302, Mean: -2.312309

# %%
# Function to visualize data from experiment
np.random.seed(42)
def visualize_experiment_data(X, Y, channel_names=None, sample_idx=None, experiment_name="Experiment"):
    """Visualize data from the experiment"""
    # Get a random sample if none provided
    if sample_idx is None:
        sample_idx = np.random.choice(range(len(X)), size=1)[0]
    
    # Get channel information
    n_channels = X.shape[4]
    n_frames = X.shape[1]
    
    # Use provided channel names or create default ones
    if channel_names is None or len(channel_names) != n_channels:
        channel_names = [f"Channel {i}" for i in range(n_channels)]
    
    # Create figure
    fig, axes = plt.subplots(n_channels, n_frames, figsize=(3*n_frames, 2*n_channels))
    if n_channels == 1:
        axes = axes.reshape(1, -1)
    
    # Plot each channel and frame
    for c in range(n_channels):
        channel_name = channel_names[c] if c < len(channel_names) else f"Channel {c}"
        
        for f in range(n_frames):
            ax = axes[c, f]
            data = X[sample_idx, f, :, :, c]
            
            im = ax.imshow(data)
            
            plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
            if f == 0:
                ax.set_ylabel(channel_name)
            ax.set_title(f"Frame {f+1}")
    
    # Set title
    plt.suptitle(f"{experiment_name}\nSample {sample_idx}")
    plt.tight_layout()
    plt.show()
    
    # Print target values
    if Y is not None:
        print(f"Target values: {Y[sample_idx]}")

# Run the visualization  
print(f"Visualizing data for {EXPERIMENT_NAME}...")
visualize_experiment_data(X_train_scaled, Y_train, channel_names=all_channel_names, experiment_name=EXPERIMENT_NAME)
# Out:
# Visualizing data for January 2022 to December 2024...
# Target values: [11.7 16.2 13.5  8.   9.3  8.6  0.   7.7]

# %% [markdown]
# # Tensorflow Model Definition

# %%
input_shape = X_train_scaled.shape[1:]  # (timesteps, height, width, channels)
output_size = Y_train.shape[1]

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv3D
from keras.layers import ConvLSTM2D
from keras.layers import BatchNormalization
from keras.layers import Convolution2D, MaxPooling3D, Flatten, Reshape
from keras.layers import TimeDistributed
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import InputLayer

tf.keras.backend.set_image_data_format('channels_last')

seq = Sequential()

seq.add(
    InputLayer(shape=input_shape)
)

seq.add(
    ConvLSTM2D(
            filters=15, 
            kernel_size=(3, 3),
            padding='same', 
            return_sequences=True
    )
)

seq.add(
    ConvLSTM2D(
        filters=30, 
        kernel_size=(3, 3),
        padding='same', 
        return_sequences=True
    )
)

seq.add(
    Conv3D(
        filters=15, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'    
    )
)

seq.add(
    Conv3D(
        filters=1, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'
    )
)

seq.add(Flatten())

seq.add(Dropout(rate=0.5))

seq.add(Dense(output_size,activation='relu'))

seq.compile(loss='mean_absolute_error', optimizer='adam')
seq.summary()
# Out:
# 2025-06-02 09:54:40.167606: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-02 09:54:40.175768: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748883280.186185   10073 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748883280.189592   10073 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-02 09:54:40.199770: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1748883281.762220   10073 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6356 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 5, 40, 40, 15)  │        11,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 5, 40, 40, 30)  │        48,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 5, 40, 40, 15)  │        12,165 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 5, 40, 40, 1)   │           406 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │        64,008 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 136,699 (533.98 KB)
#  Trainable params: 136,699 (533.98 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Model Training

# %%
print(f"\n==== Training Model for {EXPERIMENT_NAME} ====")
print(f"Training data shape: {X_train_scaled.shape}")
print(f"Target data shape: {Y_train.shape}")

history = seq.fit(X_train_scaled, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_split=0.2)

print(f"\n✓ Model training completed for {EXPERIMENT_NAME}!")
# Out:
# ==== Training Model for January 2022 to December 2024 ====
# Training data shape: (13958, 5, 40, 40, 6)
# Target data shape: (13958, 8)
# Epoch 1/100
# I0000 00:00:1748883287.372751   10169 service.cc:148] XLA service 0x7bb2040f0270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748883287.373145   10169 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2025-06-02 09:54:47.447965: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1748883287.789394   10169 cuda_dnn.cc:529] Loaded cuDNN version 90800
# 2025-06-02 09:54:48.336660: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[16,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-02 09:54:48.469758: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,6,40,40]{3,2,1,0}, f32[15,6,3,3]{3,2,1,0}, f32[15]{0}, f32[16,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
#   5/698 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - loss: 10.2910
# I0000 00:00:1748883290.239781   10169 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 697/698 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.6985
# 2025-06-02 09:55:10.054596: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[14,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[14,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[14,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-02 09:55:10.175968: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[14,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[14,6,40,40]{3,2,1,0}, f32[15,6,3,3]{3,2,1,0}, f32[15]{0}, f32[14,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.6973
# 2025-06-02 09:55:14.281282: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[8,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,6,40,40]{3,2,1,0}, f32[15,6,3,3]{3,2,1,0}, f32[15]{0}, f32[8,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-02 09:55:14.324434: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[8,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[8,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 29s 35ms/step - loss: 3.6962 - val_loss: 2.4790
# Epoch 2/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 2.2148 - val_loss: 2.1698
# Epoch 3/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 2.0514 - val_loss: 2.2025
# Epoch 4/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.9143 - val_loss: 2.0503
# Epoch 5/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.8094 - val_loss: 2.0573
# Epoch 6/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.7438 - val_loss: 1.8655
# Epoch 7/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.6790 - val_loss: 1.8539
# Epoch 8/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.6141 - val_loss: 1.9081
# Epoch 9/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.5835 - val_loss: 1.9584
# Epoch 10/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.5943 - val_loss: 1.8994
# Epoch 11/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.5653 - val_loss: 1.9406
# Epoch 12/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.5729 - val_loss: 1.9588
# Epoch 13/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.5610 - val_loss: 1.9643
# Epoch 14/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4957 - val_loss: 1.9085
# Epoch 15/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4836 - val_loss: 1.9662
# Epoch 16/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.5413 - val_loss: 1.9099
# Epoch 17/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.5032 - val_loss: 1.8347
# Epoch 18/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.4960 - val_loss: 1.8958
# Epoch 19/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.4683 - val_loss: 1.8878
# Epoch 20/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.4676 - val_loss: 1.9003
# Epoch 21/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.4678 - val_loss: 1.9480
# Epoch 22/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.4400 - val_loss: 1.9474
# Epoch 23/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4320 - val_loss: 1.9536
# Epoch 24/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.4709 - val_loss: 1.9788
# Epoch 25/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4322 - val_loss: 1.8642
# Epoch 26/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.4354 - val_loss: 1.9345
# Epoch 27/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4349 - val_loss: 1.9321
# Epoch 28/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4227 - val_loss: 1.9920
# Epoch 29/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.4034 - val_loss: 1.9337
# Epoch 30/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.4184 - val_loss: 2.0154
# Epoch 31/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.3774 - val_loss: 2.0059
# Epoch 32/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4036 - val_loss: 1.9919
# Epoch 33/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4031 - val_loss: 1.8861
# Epoch 34/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.3873 - val_loss: 1.9168
# Epoch 35/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.3906 - val_loss: 1.9163
# Epoch 36/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.3977 - val_loss: 1.9002
# Epoch 37/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3765 - val_loss: 1.9192
# Epoch 38/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3810 - val_loss: 1.9005
# Epoch 39/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3756 - val_loss: 1.8482
# Epoch 40/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3652 - val_loss: 1.9358
# Epoch 41/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3583 - val_loss: 1.9753
# Epoch 42/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3556 - val_loss: 1.9807
# Epoch 43/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.4087 - val_loss: 1.9401
# Epoch 44/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3662 - val_loss: 1.8823
# Epoch 45/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3337 - val_loss: 2.0111
# Epoch 46/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3426 - val_loss: 1.9619
# Epoch 47/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3415 - val_loss: 1.8771
# Epoch 48/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3429 - val_loss: 1.8841
# Epoch 49/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.3336 - val_loss: 1.9029
# Epoch 50/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3459 - val_loss: 1.8981
# Epoch 51/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3354 - val_loss: 1.9106
# Epoch 52/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3089 - val_loss: 1.9257
# Epoch 53/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.3264 - val_loss: 1.9560
# Epoch 54/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.3202 - val_loss: 1.9103
# Epoch 55/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.3123 - val_loss: 1.9253
# Epoch 56/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.3241 - val_loss: 1.9977
# Epoch 57/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.3047 - val_loss: 1.9968
# Epoch 58/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.3136 - val_loss: 1.9090
# Epoch 59/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.3090 - val_loss: 1.9218
# Epoch 60/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2954 - val_loss: 1.9294
# Epoch 61/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.2936 - val_loss: 1.9953
# Epoch 62/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.3003 - val_loss: 1.9672
# Epoch 63/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.2988 - val_loss: 1.8996
# Epoch 64/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.3005 - val_loss: 1.9242
# Epoch 65/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2859 - val_loss: 1.9059
# Epoch 66/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2954 - val_loss: 1.8619
# Epoch 67/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2836 - val_loss: 1.9799
# Epoch 68/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.2672 - val_loss: 1.9279
# Epoch 69/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.2809 - val_loss: 1.9477
# Epoch 70/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2690 - val_loss: 2.0505
# Epoch 71/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2840 - val_loss: 1.9233
# Epoch 72/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2766 - val_loss: 1.9188
# Epoch 73/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.2674 - val_loss: 1.9339
# Epoch 74/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2586 - val_loss: 1.9944
# Epoch 75/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2774 - val_loss: 1.9648
# Epoch 76/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.2578 - val_loss: 1.9652
# Epoch 77/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.2570 - val_loss: 1.9415
# Epoch 78/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 1.2769 - val_loss: 2.0514
# Epoch 79/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2631 - val_loss: 1.9653
# Epoch 80/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2469 - val_loss: 1.9717
# Epoch 81/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2397 - val_loss: 1.9447
# Epoch 82/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2590 - val_loss: 1.9469
# Epoch 83/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.2557 - val_loss: 1.9347
# Epoch 84/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2527 - val_loss: 1.9749
# Epoch 85/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.2502 - val_loss: 2.0339
# Epoch 86/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - loss: 1.2516 - val_loss: 2.1253
# Epoch 87/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2361 - val_loss: 2.0277
# Epoch 88/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2352 - val_loss: 2.0651
# Epoch 89/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2571 - val_loss: 2.0398
# Epoch 90/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.2369 - val_loss: 2.0968
# Epoch 91/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2534 - val_loss: 1.9557
# Epoch 92/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2280 - val_loss: 2.0561
# Epoch 93/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2218 - val_loss: 2.0564
# Epoch 94/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 1.2388 - val_loss: 2.1072
# Epoch 95/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.2356 - val_loss: 2.0474
# Epoch 96/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.2280 - val_loss: 2.1066
# Epoch 97/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.2193 - val_loss: 1.9651
# Epoch 98/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.2261 - val_loss: 1.9721
# Epoch 99/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.2263 - val_loss: 2.1312
# Epoch 100/100
# 698/698 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.2076 - val_loss: 2.1941
#
# ✓ Model training completed for January 2022 to December 2024!

# %% [markdown]
# # Model Evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import os
from datetime import datetime

# Create output directory for results
output_dir = f"experiment_output/{EXPERIMENT_ID}"
os.makedirs(output_dir, exist_ok=True)

# Evaluate model
print(f"\nEvaluating model for {EXPERIMENT_NAME}...")
y_pred = seq.predict(X_test_scaled, verbose=0)

# Calculate metrics on real scale
mae_real = mean_absolute_error(Y_test, y_pred)
rmse_real = np.sqrt(mean_squared_error(Y_test, y_pred))
r2_real = r2_score(Y_test, y_pred)

print(f"\nFinal Results for {EXPERIMENT_NAME} (Real PM2.5 Scale):")
print(f"Mean Absolute Error: {mae_real:.4f} μg/m³")
print(f"Root Mean Squared Error: {rmse_real:.4f} μg/m³")
print(f"R² Score: {r2_real:.4f}")


# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title(f'{EXPERIMENT_NAME}\nTraining Loss (Scaled Targets)')
plt.xlabel('Epoch')
plt.ylabel('Loss (MAE)')
plt.grid(True, alpha=0.3)
plt.show()

# Save results (save both scaled and real versions)
results_dir = os.path.join(output_dir, "results")
os.makedirs(results_dir, exist_ok=True)

# Save real scale results for analysis
np.save(os.path.join(results_dir, "y_pred.npy"), y_pred)
np.save(os.path.join(results_dir, "Y_test.npy"), Y_test)

# Save model and scaler
seq.save(os.path.join(results_dir, "model.keras"))

print(f"\n✓ Evaluation completed for {EXPERIMENT_NAME}")
print(f"Results saved to: {results_dir}")
# Out:
# Evaluating model for January 2022 to December 2024...
# 2025-06-02 10:31:50.856285: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,6,40,40]{3,2,1,0}, f32[15,6,3,3]{3,2,1,0}, f32[15]{0}, f32[32,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-02 10:31:50.911163: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[32,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-02 10:31:53.536063: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,6,40,40]{3,2,1,0}, f32[15,6,3,3]{3,2,1,0}, f32[15]{0}, f32[2,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-02 10:31:53.591562: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[2,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# Final Results for January 2022 to December 2024 (Real PM2.5 Scale):
# Mean Absolute Error: 2.1714 μg/m³
# Root Mean Squared Error: 4.6197 μg/m³
# R² Score: 0.7164
# ✓ Evaluation completed for January 2022 to December 2024
# Results saved to: experiment_output/two_years_pwwb_airnow_hrrr/results

# %% [markdown]
# # Detailed Analysis

# %%
print(f"\nDetailed analysis for {EXPERIMENT_NAME}:")
print(f"Description: {EXPERIMENT_DESCRIPTION}")
print(f"Date range: {START_DATE} to {END_DATE}")
print(f"Temporal split: {TRAIN_SPLIT*100:.0f}%/{(1-TRAIN_SPLIT)*100:.0f}%")
print(f"Total sensors: {Y_test.shape[1]}")
# Out:
# Detailed analysis for January 2022 to December 2024:
# Description: January 2025 fire period with PWWB, Airnow, and HRRR data.
# Date range: 2022-12-01-00 to 2024-12-01-00
# Temporal split: 80%/20%
# Total sensors: 8

# %%
import matplotlib.pyplot as plt

# Check target distribution
Y_flat = Y_train.flatten()
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(Y_flat, bins=50, alpha=0.7)
plt.title('Scaled Target Distribution')
plt.xlabel('Scaled Value')

plt.subplot(1, 2, 2)
plt.hist(Y_flat[Y_flat < 2], bins=50, alpha=0.7)  # Zoom in on normal range
plt.title('Scaled Targets (< 2.0)')
plt.xlabel('Scaled Value')

plt.tight_layout()
plt.show()

print(f"Percentage of targets > 5.0: {(Y_flat > 5.0).mean()*100:.1f}%")
print(f"Percentage of targets > 2.0: {(Y_flat > 2.0).mean()*100:.1f}%")
# Out:
# Percentage of targets > 5.0: 73.2%
# Percentage of targets > 2.0: 89.8%

# %%
print("Original targets:")
print(f"Y_train range: {Y_train.min():.3f} to {Y_train.max():.3f}")
# Out:
# Original targets:
# Y_train range: 0.000 to 279.700

# %%
import sys
sys.path.append("..")

from libs.plotting import (
    plot_prediction_comparison,
    plot_scatter_comparison,
    plot_error_by_sensor,
    plot_time_series_comparison,
    plot_input_frames,
    print_metrics
)

# Get sensor names
sensor_names = [
    'Simi Valley - Cochran Street', 'Reseda', 'Santa Clarita', 'North Holywood', 
    'Los Angeles - N. Main Street', 'Compton', 'Long Beach Signal Hill', 'Glendora - Laurel'
]

print(f"\nSensors in {EXPERIMENT_NAME}: {sensor_names}")

print("\n1. Plotting prediction comparison...")
plot_prediction_comparison(y_pred, Y_test, sensor_names, sample_idx=8)

print("\n2. Plotting scatter comparison...")
plot_scatter_comparison(y_pred, Y_test)

print("\n3. Plotting error by sensor...")
plot_error_by_sensor(y_pred, Y_test, sensor_names)

print("\n4. Plotting time series comparison...")
plot_time_series_comparison(y_pred, Y_test, sensor_names)
    
print("\n5. Plotting time series with shifted predictions...")
plot_time_series_comparison(y_pred, Y_test, sensor_names, shift_pred=1)

print("\n6. Printing detailed metrics...")
print_metrics(y_pred, Y_test, sensor_names)
# Out:
# Sensors in January 2022 to December 2024: ['Simi Valley - Cochran Street', 'Reseda', 'Santa Clarita', 'North Holywood', 'Los Angeles - N. Main Street', 'Compton', 'Long Beach Signal Hill', 'Glendora - Laurel']
#
# 1. Plotting prediction comparison...
# 2. Plotting scatter comparison...
# 3. Plotting error by sensor...
# 4. Plotting time series comparison...
# 5. Plotting time series with shifted predictions...
# 6. Printing detailed metrics...
# RESULTS
# ---------------------------------------------------------------------------
# All Days All Locations - y_pred vs y_test Raw RMSE: 4.62
# All Days All Locations - y_pred vs y_test RMSE Percent Error of Mean: 41.68%
#
# RESULTS BY FRAME
# ---------------------------------------------------------------------------
# Frame 1 (Hour 1) All Locations - Raw RMSE: 1.83
# Frame 1 (Hour 1) All Locations - RMSE Percent Error of Mean: 13.61%
#
# Frame 2 (Hour 2) All Locations - Raw RMSE: 1.20
# Frame 2 (Hour 2) All Locations - RMSE Percent Error of Mean: 8.87%
#
# Frame 3 (Hour 3) All Locations - Raw RMSE: 1.68
# Frame 3 (Hour 3) All Locations - RMSE Percent Error of Mean: 12.87%
#
# Frame 4 (Hour 4) All Locations - Raw RMSE: 1.33
# Frame 4 (Hour 4) All Locations - RMSE Percent Error of Mean: 10.27%
#
# Frame 5 (Hour 5) All Locations - Raw RMSE: 1.18
# Frame 5 (Hour 5) All Locations - RMSE Percent Error of Mean: 9.58%
#
# Frame 6 (Hour 6) All Locations - Raw RMSE: 2.46
# Frame 3378 (Hour 3378) All Locations - Raw RMSE: 4.71
# Frame 3378 (Hour 3378) All Locations - RMSE Percent Error of Mean: 38.30%
#
# Frame 3379 (Hour 3379) All Locations - Raw RMSE: 5.26
# Frame 3379 (Hour 3379) All Locations - RMSE Percent Error of Mean: 43.59%
#
# Frame 3380 (Hour 3380) All Locations - Raw RMSE: 5.50
# Frame 3380 (Hour 3380) All Locations - RMSE Percent Error of Mean: 42.90%
#
# Frame 3381 (Hour 3381) All Locations - Raw RMSE: 4.92
# Frame 3381 (Hour 3381) All Locations - RMSE Percent Error of Mean: 36.26%
#
# Frame 3382 (Hour 3382) All Locations - Raw RMSE: 5.20
# Frame 3382 (Hour 3382) All Locations - RMSE Percent Error of Mean: 35.35%
#
# Frame 3383 (Hour 3383) All Locations - Raw RMSE: 5.56
# Frame 3383 (Hour 3383) All Locations - RMSE Percent Error of Mean: 40.76%
#
# Frame 3384 (Hour 3384) All Locations - Raw RMSE: 4.12
# Frame 3384 (Hour 3384) All Locations - RMSE Percent Error of Mean: 31.80%
#
# Frame 3385 (Hour 3385) All Locations - Raw RMSE: 5.81
# Frame 3385 (Hour 3385) All Locations - RMSE Percent Error of Mean: 49.40%
#
# Frame 3386 (Hour 3386) All Locations - Raw RMSE: 4.83
# Frame 3386 (Hour 3386) All Locations - RMSE Percent Error of Mean: 43.49%
#
# Frame 3387 (Hour 3387) All Locations - Raw RMSE: 4.59
# Frame 3387 (Hour 3387) All Locations - RMSE Percent Error of Mean: 41.95%
#
# Frame 3388 (Hour 3388) All Locations - Raw RMSE: 4.96
# Frame 3388 (Hour 3388) All Locations - RMSE Percent Error of Mean: 47.16%
#
# Frame 3389 (Hour 3389) All Locations - Raw RMSE: 3.48
# Frame 3389 (Hour 3389) All Locations - RMSE Percent Error of Mean: 34.59%
#
# Frame 3390 (Hour 3390) All Locations - Raw RMSE: 2.79
# Frame 3390 (Hour 3390) All Locations - RMSE Percent Error of Mean: 26.47%
#
# Frame 3391 (Hour 3391) All Locations - Raw RMSE: 1.99
# Frame 3391 (Hour 3391) All Locations - RMSE Percent Error of Mean: 20.61%
#
# Frame 3392 (Hour 3392) All Locations - Raw RMSE: 2.86
# Frame 3392 (Hour 3392) All Locations - RMSE Percent Error of Mean: 28.71%
#
# Frame 3393 (Hour 3393) All Locations - Raw RMSE: 1.85
# Frame 3393 (Hour 3393) All Locations - RMSE Percent Error of Mean: 19.74%
#
# Frame 3394 (Hour 3394) All Locations - Raw RMSE: 1.97
# Frame 3394 (Hour 3394) All Locations - RMSE Percent Error of Mean: 19.71%
#
# Frame 3395 (Hour 3395) All Locations - Raw RMSE: 2.31
# Frame 3395 (Hour 3395) All Locations - RMSE Percent Error of Mean: 20.35%
#
# Frame 3396 (Hour 3396) All Locations - Raw RMSE: 3.22
# Frame 3396 (Hour 3396) All Locations - RMSE Percent Error of Mean: 25.12%
#
# Frame 3397 (Hour 3397) All Locations - Raw RMSE: 2.07
# Frame 3397 (Hour 3397) All Locations - RMSE Percent Error of Mean: 15.14%
#
# Frame 3398 (Hour 3398) All Locations - Raw RMSE: 1.94
# Frame 3398 (Hour 3398) All Locations - RMSE Percent Error of Mean: 13.56%
#
# Frame 3399 (Hour 3399) All Locations - Raw RMSE: 1.90
# Frame 3399 (Hour 3399) All Locations - RMSE Percent Error of Mean: 14.05%
#
# Frame 3400 (Hour 3400) All Locations - Raw RMSE: 2.07
# Frame 3400 (Hour 3400) All Locations - RMSE Percent Error of Mean: 15.46%
#
# Frame 3401 (Hour 3401) All Locations - Raw RMSE: 0.85
# Frame 3401 (Hour 3401) All Locations - RMSE Percent Error of Mean: 6.23%
#
# Frame 3402 (Hour 3402) All Locations - Raw RMSE: 1.82
# Frame 3402 (Hour 3402) All Locations - RMSE Percent Error of Mean: 14.08%
#
# Frame 3403 (Hour 3403) All Locations - Raw RMSE: 1.90
# Frame 3403 (Hour 3403) All Locations - RMSE Percent Error of Mean: 14.74%
#
# Frame 3404 (Hour 3404) All Locations - Raw RMSE: 2.13
# Frame 3404 (Hour 3404) All Locations - RMSE Percent Error of Mean: 16.35%
#
# Frame 3405 (Hour 3405) All Locations - Raw RMSE: 1.42
# Frame 3405 (Hour 3405) All Locations - RMSE Percent Error of Mean: 10.47%
#
# Frame 3406 (Hour 3406) All Locations - Raw RMSE: 1.78
# Frame 3406 (Hour 3406) All Locations - RMSE Percent Error of Mean: 12.77%
#
# Frame 3407 (Hour 3407) All Locations - Raw RMSE: 2.38
# Frame 3407 (Hour 3407) All Locations - RMSE Percent Error of Mean: 16.18%
#
# Frame 3408 (Hour 3408) All Locations - Raw RMSE: 2.91
# Frame 3408 (Hour 3408) All Locations - RMSE Percent Error of Mean: 22.31%
#
# Frame 3409 (Hour 3409) All Locations - Raw RMSE: 1.56
# Frame 3409 (Hour 3409) All Locations - RMSE Percent Error of Mean: 13.39%
#
# Frame 3410 (Hour 3410) All Locations - Raw RMSE: 2.03
# Frame 3410 (Hour 3410) All Locations - RMSE Percent Error of Mean: 18.46%
#
# Frame 3411 (Hour 3411) All Locations - Raw RMSE: 1.84
# Frame 3411 (Hour 3411) All Locations - RMSE Percent Error of Mean: 18.04%
#
# Frame 3412 (Hour 3412) All Locations - Raw RMSE: 2.25
# Frame 3412 (Hour 3412) All Locations - RMSE Percent Error of Mean: 21.94%
#
# Frame 3413 (Hour 3413) All Locations - Raw RMSE: 2.11
# Frame 3413 (Hour 3413) All Locations - RMSE Percent Error of Mean: 20.35%
#
# Frame 3414 (Hour 3414) All Locations - Raw RMSE: 1.75
# Frame 3414 (Hour 3414) All Locations - RMSE Percent Error of Mean: 17.43%
#
# Frame 3415 (Hour 3415) All Locations - Raw RMSE: 1.83
# Frame 3415 (Hour 3415) All Locations - RMSE Percent Error of Mean: 18.47%
#
# Frame 3416 (Hour 3416) All Locations - Raw RMSE: 3.45
# Frame 3416 (Hour 3416) All Locations - RMSE Percent Error of Mean: 28.88%
#
# Frame 3417 (Hour 3417) All Locations - Raw RMSE: 2.73
# Frame 3417 (Hour 3417) All Locations - RMSE Percent Error of Mean: 21.32%
#
# Frame 3438 (Hour 3438) All Locations - Raw RMSE: 1.27
# Frame 3438 (Hour 3438) All Locations - RMSE Percent Error of Mean: 40.21%
#
# Frame 3439 (Hour 3439) All Locations - Raw RMSE: 0.72
# Frame 3439 (Hour 3439) All Locations - RMSE Percent Error of Mean: 16.18%
#
# Frame 3440 (Hour 3440) All Locations - Raw RMSE: 2.41
# Frame 3440 (Hour 3440) All Locations - RMSE Percent Error of Mean: 41.31%
#
# Frame 3441 (Hour 3441) All Locations - Raw RMSE: 1.46
# Frame 3441 (Hour 3441) All Locations - RMSE Percent Error of Mean: 22.10%
#
# Frame 3442 (Hour 3442) All Locations - Raw RMSE: 2.18
# Frame 3442 (Hour 3442) All Locations - RMSE Percent Error of Mean: 28.01%
#
# Frame 3443 (Hour 3443) All Locations - Raw RMSE: 1.52
# Frame 3443 (Hour 3443) All Locations - RMSE Percent Error of Mean: 16.42%
#
# Frame 3444 (Hour 3444) All Locations - Raw RMSE: 1.96
# Frame 3444 (Hour 3444) All Locations - RMSE Percent Error of Mean: 18.63%
#
# Frame 3445 (Hour 3445) All Locations - Raw RMSE: 1.16
# Frame 3445 (Hour 3445) All Locations - RMSE Percent Error of Mean: 11.29%
#
# Frame 3446 (Hour 3446) All Locations - Raw RMSE: 3.04
# Frame 3446 (Hour 3446) All Locations - RMSE Percent Error of Mean: 27.11%
#
# Frame 3447 (Hour 3447) All Locations - Raw RMSE: 1.42
# Frame 3447 (Hour 3447) All Locations - RMSE Percent Error of Mean: 12.69%
#
# Frame 3448 (Hour 3448) All Locations - Raw RMSE: 1.42
# Frame 3448 (Hour 3448) All Locations - RMSE Percent Error of Mean: 13.16%
#
# Frame 3449 (Hour 3449) All Locations - Raw RMSE: 2.64
# Frame 3449 (Hour 3449) All Locations - RMSE Percent Error of Mean: 23.46%
#
# Frame 3450 (Hour 3450) All Locations - Raw RMSE: 2.29
# Frame 3450 (Hour 3450) All Locations - RMSE Percent Error of Mean: 22.01%
#
# Frame 3451 (Hour 3451) All Locations - Raw RMSE: 0.86
# Frame 3451 (Hour 3451) All Locations - RMSE Percent Error of Mean: 9.46%
#
# Frame 3452 (Hour 3452) All Locations - Raw RMSE: 2.11
# Frame 3452 (Hour 3452) All Locations - RMSE Percent Error of Mean: 22.14%
#
# Frame 3453 (Hour 3453) All Locations - Raw RMSE: 1.77
# Frame 3453 (Hour 3453) All Locations - RMSE Percent Error of Mean: 18.45%
#
# Frame 3454 (Hour 3454) All Locations - Raw RMSE: 1.36
# Frame 3454 (Hour 3454) All Locations - RMSE Percent Error of Mean: 12.85%
#
# Frame 3455 (Hour 3455) All Locations - Raw RMSE: 2.80
# Frame 3455 (Hour 3455) All Locations - RMSE Percent Error of Mean: 23.83%
#
# Frame 3456 (Hour 3456) All Locations - Raw RMSE: 2.59
# Frame 3456 (Hour 3456) All Locations - RMSE Percent Error of Mean: 21.18%
#
# Frame 3457 (Hour 3457) All Locations - Raw RMSE: 1.69
# Frame 3457 (Hour 3457) All Locations - RMSE Percent Error of Mean: 15.78%
#
# Frame 3458 (Hour 3458) All Locations - Raw RMSE: 0.98
# Frame 3458 (Hour 3458) All Locations - RMSE Percent Error of Mean: 10.47%
#
# Frame 3459 (Hour 3459) All Locations - Raw RMSE: 1.45
# Frame 3459 (Hour 3459) All Locations - RMSE Percent Error of Mean: 16.35%
#
# Frame 3460 (Hour 3460) All Locations - Raw RMSE: 1.15
# Frame 3460 (Hour 3460) All Locations - RMSE Percent Error of Mean: 14.09%
#
# Frame 3461 (Hour 3461) All Locations - Raw RMSE: 2.73
# Frame 3461 (Hour 3461) All Locations - RMSE Percent Error of Mean: 36.91%
#
# Frame 3462 (Hour 3462) All Locations - Raw RMSE: 1.49
# Frame 3462 (Hour 3462) All Locations - RMSE Percent Error of Mean: 19.47%
#
# Frame 3463 (Hour 3463) All Locations - Raw RMSE: 3.47
# Frame 3463 (Hour 3463) All Locations - RMSE Percent Error of Mean: 33.52%
#
# Frame 3464 (Hour 3464) All Locations - Raw RMSE: 3.11
# Frame 3464 (Hour 3464) All Locations - RMSE Percent Error of Mean: 25.24%
#
# Frame 3465 (Hour 3465) All Locations - Raw RMSE: 2.64
# Frame 3465 (Hour 3465) All Locations - RMSE Percent Error of Mean: 18.89%
#
# Frame 3466 (Hour 3466) All Locations - Raw RMSE: 2.25
# Frame 3466 (Hour 3466) All Locations - RMSE Percent Error of Mean: 15.40%
#
# Frame 3467 (Hour 3467) All Locations - Raw RMSE: 2.65
# Frame 3467 (Hour 3467) All Locations - RMSE Percent Error of Mean: 17.64%
#
# Frame 3468 (Hour 3468) All Locations - Raw RMSE: 2.31
# Frame 3468 (Hour 3468) All Locations - RMSE Percent Error of Mean: 15.28%
#
# Frame 3469 (Hour 3469) All Locations - Raw RMSE: 1.79
# Frame 3469 (Hour 3469) All Locations - RMSE Percent Error of Mean: 11.81%
#
# Frame 3470 (Hour 3470) All Locations - Raw RMSE: 2.41
# Frame 3470 (Hour 3470) All Locations - RMSE Percent Error of Mean: 16.38%
#
# Frame 3471 (Hour 3471) All Locations - Raw RMSE: 1.98
# Frame 3471 (Hour 3471) All Locations - RMSE Percent Error of Mean: 14.03%
#
# Frame 3472 (Hour 3472) All Locations - Raw RMSE: 3.29
# Frame 3472 (Hour 3472) All Locations - RMSE Percent Error of Mean: 24.88%
#
# Frame 3473 (Hour 3473) All Locations - Raw RMSE: 2.23
# Frame 3473 (Hour 3473) All Locations - RMSE Percent Error of Mean: 18.17%
#
# Frame 3474 (Hour 3474) All Locations - Raw RMSE: 2.03
# Frame 3474 (Hour 3474) All Locations - RMSE Percent Error of Mean: 17.79%
#
# Frame 3475 (Hour 3475) All Locations - Raw RMSE: 1.96
# Frame 3475 (Hour 3475) All Locations - RMSE Percent Error of Mean: 17.47%
#
# Frame 3476 (Hour 3476) All Locations - Raw RMSE: 2.54
# Frame 3476 (Hour 3476) All Locations - RMSE Percent Error of Mean: 22.53%
#
# Frame 3477 (Hour 3477) All Locations - Raw RMSE: 1.43
# Frame 3477 (Hour 3477) All Locations - RMSE Percent Error of Mean: 12.89%
#
# Frame 3478 (Hour 3478) All Locations - Raw RMSE: 3.30
# Frame 3478 (Hour 3478) All Locations - RMSE Percent Error of Mean: 31.79%
#
# Frame 3479 (Hour 3479) All Locations - Raw RMSE: 2.49
# Frame 3479 (Hour 3479) All Locations - RMSE Percent Error of Mean: 24.27%
#
# Frame 3480 (Hour 3480) All Locations - Raw RMSE: 2.10
# Frame 3480 (Hour 3480) All Locations - RMSE Percent Error of Mean: 23.34%
#
# Frame 3481 (Hour 3481) All Locations - Raw RMSE: 2.13
# Frame 3481 (Hour 3481) All Locations - RMSE Percent Error of Mean: 30.12%
#
# Frame 3482 (Hour 3482) All Locations - Raw RMSE: 2.12
# Frame 3482 (Hour 3482) All Locations - RMSE Percent Error of Mean: 40.68%
#
# Frame 3483 (Hour 3483) All Locations - Raw RMSE: 1.71
# Frame 3483 (Hour 3483) All Locations - RMSE Percent Error of Mean: 43.36%
#
# Frame 3484 (Hour 3484) All Locations - Raw RMSE: 1.33
# Frame 3484 (Hour 3484) All Locations - RMSE Percent Error of Mean: 43.09%
#
# Frame 3485 (Hour 3485) All Locations - Raw RMSE: 1.09
# Frame 3485 (Hour 3485) All Locations - RMSE Percent Error of Mean: 54.77%
#
# Frame 3486 (Hour 3486) All Locations - Raw RMSE: 1.37
# Frame 3486 (Hour 3486) All Locations - RMSE Percent Error of Mean: 75.21%
#
# Frame 3487 (Hour 3487) All Locations - Raw RMSE: 1.13
# Frame 3487 (Hour 3487) All Locations - RMSE Percent Error of Mean: 39.93%
#
# Frame 3488 (Hour 3488) All Locations - Raw RMSE: 1.48
# Frame 3488 (Hour 3488) All Locations - RMSE Percent Error of Mean: 40.43%
#
# Frame 3489 (Hour 3489) All Locations - Raw RMSE: 1.25
# Frame 3489 (Hour 3489) All Locations - RMSE Percent Error of Mean: 26.42%
#
# Frame 3490 (Hour 3490) All Locations - Raw RMSE: 1.44
# Frame 3490 (Hour 3490) All Locations - RMSE Percent Error of Mean: 28.97%
#
# RESULTS BY SENSOR LOCATION
# ---------------------------------------------------------------------------
# All Days - Simi Valley - Cochran Street Raw RMSE: 2.54
# All Days - Simi Valley - Cochran Street RMSE Percent Error of Mean: 33.41%
#
# All Days - Reseda Raw RMSE: 2.70
# All Days - Reseda RMSE Percent Error of Mean: 26.70%
#
# All Days - Santa Clarita Raw RMSE: 2.54
# All Days - Santa Clarita RMSE Percent Error of Mean: 21.50%
#
# All Days - North Holywood Raw RMSE: 3.81
# All Days - North Holywood RMSE Percent Error of Mean: 29.57%
#
# All Days - Los Angeles - N. Main Street Raw RMSE: 4.20
# All Days - Los Angeles - N. Main Street RMSE Percent Error of Mean: 28.83%
#
# All Days - Compton Raw RMSE: 5.77
# All Days - Compton RMSE Percent Error of Mean: 55.37%
#
# All Days - Long Beach Signal Hill Raw RMSE: 4.44
# All Days - Long Beach Signal Hill RMSE Percent Error of Mean: 48.94%
#
# All Days - Glendora - Laurel Raw RMSE: 8.08
# All Days - Glendora - Laurel RMSE Percent Error of Mean: 66.36%
