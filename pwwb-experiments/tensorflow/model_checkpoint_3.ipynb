# %% [markdown]
# # Data Parameters
# Input
# - Frames: 5 in 1 out
# - Target: 1 station (LA N. Main St.)
# - Channels: AirNow, Wind U/V
#
# Model
# - Classic
# ```
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 5, 40, 40, 15)  │         9,780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 5, 40, 40, 30)  │        48,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 5, 40, 40, 15)  │        12,165 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 5, 40, 40, 1)   │           406 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         8,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
# ```
# - Adam 1e-4 LR, 1e-2 WD
#
# Result
# - 15.71 NRMSE
#
# General Notes
# - I think this is where ablation would be nice. Wind helps; I would like to see if other channels in isolation help before committing to combining them.
# - I noticed valid loss is quite unstable; I tried l2 regularization in each layer (0.01 and 0.1). While it improved the "jumpiness" of the valid loss, both train and valid loss would converge on a slightly higher error, ultimately being a negative addition to the model. Only by like 1-2% NRMSE, but negative nonetheless.

# %%
# Data parameters
START_DATE = "2022-12-01-00"
END_DATE = "2024-12-01-00"

# Define bounding box
lat_bottom, lat_top = 33.5, 34.5
lon_bottom, lon_top = -118.75, -117.0
extent = (lon_bottom, lon_top, lat_bottom, lat_top)

# Input data shape
dim = 40
frames_per_sample = 5

print(f"{extent}")
print(f"Grid dimension: {dim}x{dim}")
print(f"Frames per sample: {frames_per_sample}")
# Out:
# (-118.75, -117.0, 33.5, 34.5)
# Grid dimension: 40x40
# Frames per sample: 5

# %% [markdown]
# # Data Ingestion and Preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import os
from datetime import datetime
import sys
sys.path.append("../..")
#from libs.sequence import PWWBPyDataset

# %%
X_test_files = ["METAR_Wind_U_X_test.npy", "METAR_Wind_V_X_test.npy", "AirNow_PM25_X_test.npy"]
X_train_files = ["METAR_Wind_U_X_train.npy", "METAR_Wind_V_X_train.npy", "AirNow_PM25_X_train.npy"]
X_valid_files = ["METAR_Wind_U_X_valid.npy", "METAR_Wind_V_X_valid.npy", "AirNow_PM25_X_valid.npy"]

Y_test_files = "Y_test.npy"
Y_train_files = "Y_train.npy"
Y_valid_files = "Y_valid.npy"

# %%
''' y is not trimmed, can't use this method
BATCH_SIZE = 32
X_training_files_paths = [f"{path + file}" for file in X_train_files]
Y_training_files_paths = f"{path + Y_train_files}"
generator = PWWBPyDataset(X_training_files_paths, Y_training_files_paths, BATCH_SIZE, workers=8, use_multiprocessing=True)

history = seq.fit(
    generator,
    epochs=EPOCHS,
    validation_data=(X_valid_scaled, Y_valid),
    callbacks=callbacks
)
'''
path = "final_input_data/two_years_with_hrrr/"
X_train = np.stack([np.load(f"{path + file}") for file in X_train_files], axis=-1)
X_test = np.stack([np.load(f"{path + file}") for file in X_test_files], axis=-1)
X_valid = np.stack([np.load(f"{path + file}") for file in X_valid_files], axis=-1)

Y_train = np.load(f"{path + Y_train_files}")
Y_test = np.load(f"{path + Y_test_files}")
Y_valid = np.load(f"{path + Y_valid_files}")

# %%
# 5 frames in, one frame and one station out
# next frame = 0
# LA station = 4
Y_train_trimmed = Y_train[:, 0, [4]].copy()
Y_test_trimmed = Y_test[:, 0, [4]].copy()
Y_valid_trimmed = Y_valid[:, 0, [4]].copy()

# %% [markdown]
# # Model Definition

# %%
output_size = 1
input_shape = X_train.shape[1:] # (frames, height, width, channels)

print(
    f"X_train shape: {X_train.shape}\n"
    f"Y_train shape: {Y_train_trimmed.shape}\n\n"
    
    f"X_test shape:  {X_test.shape}\n"
    f"Y_test shape:  {Y_test_trimmed.shape}\n\n"

    f"X_valid shape: {X_valid.shape}\n"
    f"Y_valid shape: {Y_valid_trimmed.shape}\n\n"

    f"Input shape:   {input_shape}\n"
    f"Output shape:  ({output_size})\n"
)
# Out:
# X_train shape: (12274, 5, 40, 40, 3)
# Y_train shape: (12274, 1)
#
# X_test shape:  (2631, 5, 40, 40, 3)
# Y_test shape:  (2631, 1)
#
# X_valid shape: (2630, 5, 40, 40, 3)
# Y_valid shape: (2630, 1)
#
# Input shape:   (5, 40, 40, 3)
# Output shape:  (1)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv3D
from keras.layers import ConvLSTM2D
from keras.layers import BatchNormalization, LayerNormalization
from keras.layers import Convolution2D, MaxPooling3D, Flatten, Reshape, GlobalAveragePooling2D
from keras.layers import TimeDistributed
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import InputLayer

tf.keras.backend.set_image_data_format('channels_last')

seq = Sequential()

seq.add(
    InputLayer(shape=input_shape)
)

seq.add(
    ConvLSTM2D(
        filters=15, 
        kernel_size=(3, 3),
        padding='same', 
        return_sequences=True,
        #dropout=0.1,
        #recurrent_dropout=0.1,
        #kernel_regularizer=keras.regularizers.l2(0.01)
    )
)

seq.add(
    ConvLSTM2D(
        filters=30, 
        kernel_size=(3, 3),
        padding='same', 
        return_sequences=True,
        #dropout=0.1,
        #recurrent_dropout=0.1,
        #kernel_regularizer=keras.regularizers.l2(0.01)
    )
)

seq.add(
    Conv3D(
        filters=15, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'    
    )
)

seq.add(
    Conv3D(
        filters=1, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'
    )
)

# applies layer to every temporal slice (first dimension)
# so for (5, 40, 40, 1), the layer is applied to each frame, a total of 5 times
#seq.add(TimeDistributed(Flatten()))
seq.add(Flatten())

#seq.add(Dropout(rate=0.1))

seq.add(Dense(output_size, activation='relu'))

seq.compile(
    loss='mean_absolute_error', 
    optimizer=keras.optimizers.Adam(learning_rate=0.0001, weight_decay=0.01)
)
seq.summary()
# Out:
# 2025-07-03 15:18:24.486803: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-03 15:18:24.495090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751581104.506399   41137 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751581104.509882   41137 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-03 15:18:24.521379: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1751581105.760832   41137 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6203 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 5, 40, 40, 15)  │         9,780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 5, 40, 40, 30)  │        48,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 5, 40, 40, 15)  │        12,165 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 5, 40, 40, 1)   │           406 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         8,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,072 (308.88 KB)
#  Trainable params: 79,072 (308.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
import os
import time

# tensorboard gradient logging callback
# at the end of an epoch, pass in a sample batch and calculate the gradients
class GradientLogger(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, data_sample):
        super().__init__()
        self.writer = tf.summary.create_file_writer(log_dir)
        self.data_sample = data_sample  # A batch of (x, y) from your training data

    def on_epoch_end(self, epoch, logs=None):
        # log gradients
        x, y = self.data_sample

        with tf.GradientTape() as tape:
            loss = self.model.compute_loss(
                y=y, 
                y_pred=self.model(x, training=True)
            )

        gradients = tape.gradient(loss, self.model.trainable_weights)
        grad_norm = tf.linalg.global_norm(gradients)

        # plot gradients
        with self.writer.as_default():
            tf.summary.scalar("gradient_norm/global", grad_norm, step=epoch)
            
            for weight, grad in zip(self.model.trainable_weights, gradients):
                if grad is not None:
                    tf.summary.histogram(f"gradients/{weight.name}", grad, step=epoch)
            self.writer.flush()

# tensorboard callback setup
def get_run_logdir(
    root_logdir, 
    run_id=time.strftime("run_%Y_%m_%d-%H_%M_%S")
):
    return os.path.join(root_logdir, run_id)
    
run_logdir = get_run_logdir(
    root_logdir=os.path.join(os.curdir, "my_logs"),
    run_id="default"
)

# model checkpoint callback setup
checkpoint_filepath = 'experiment_output/basic_experiments/model.keras'

# define list of callbacks we're gonna use
callbacks = [
    EarlyStopping(monitor='val_loss', patience=30),
    ModelCheckpoint(
        filepath=checkpoint_filepath,
        monitor='val_loss',
        mode='min',
        save_best_only=True
    ),
    #TensorBoard(run_logdir, histogram_freq=1),
    #GradientLogger(run_logdir, data_sample=(X_test_scaled[:32], Y_test[:32]))
]

# %%
history = seq.fit(
    X_train,
    Y_train_trimmed,
    epochs=200,
    batch_size=32,
    validation_data=(X_valid, Y_valid_trimmed),
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# I0000 00:00:1751581109.830862   41234 service.cc:148] XLA service 0x79f09400c050 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751581109.830887   41234 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2025-07-03 15:18:29.896281: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1751581110.189290   41234 cuda_dnn.cc:529] Loaded cuDNN version 90800
# 2025-07-03 15:18:30.694296: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[32,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-07-03 15:18:30.854971: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,40,40]{3,2,1,0}, f32[15,3,3,3]{3,2,1,0}, f32[15]{0}, f32[32,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
#   3/384 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 10.2165
# I0000 00:00:1751581112.904014   41234 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 383/384 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.8702
# 2025-07-03 15:18:55.224961: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[18,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[18,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-07-03 15:18:55.366843: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[18,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,3,40,40]{3,2,1,0}, f32[15,3,3,3]{3,2,1,0}, f32[15]{0}, f32[18,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 5.8663
# 2025-07-03 15:18:59.939923: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[6,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[6,3,40,40]{3,2,1,0}, f32[15,3,3,3]{3,2,1,0}, f32[15]{0}, f32[6,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-07-03 15:18:59.989236: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[6,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[6,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[6,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 33s 72ms/step - loss: 5.8623 - val_loss: 3.1938
# Epoch 2/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - loss: 3.2672 - val_loss: 3.0716
# Epoch 3/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - loss: 3.0946 - val_loss: 2.8541
# Epoch 4/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - loss: 3.0021 - val_loss: 2.7880
# Epoch 5/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - loss: 2.8694 - val_loss: 2.7075
# Epoch 6/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - loss: 2.8671 - val_loss: 2.7955
# Epoch 7/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - loss: 2.7966 - val_loss: 3.0010
# Epoch 8/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 2.6797 - val_loss: 2.6761
# Epoch 9/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 2.5670 - val_loss: 2.5647
# Epoch 10/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 2.5393 - val_loss: 2.4733
# Epoch 11/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 2.3995 - val_loss: 2.4942
# Epoch 12/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.3312 - val_loss: 2.8837
# Epoch 13/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.3056 - val_loss: 2.8140
# Epoch 14/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.2791 - val_loss: 2.5714
# Epoch 15/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.2598 - val_loss: 2.2412
# Epoch 16/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.1737 - val_loss: 2.1814
# Epoch 17/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.1263 - val_loss: 2.1317
# Epoch 18/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.0704 - val_loss: 2.0410
# Epoch 19/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.0195 - val_loss: 2.0957
# Epoch 20/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 2.0301 - val_loss: 2.0611
# Epoch 21/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.9901 - val_loss: 2.1425
# Epoch 22/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.9408 - val_loss: 2.0203
# Epoch 23/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.9217 - val_loss: 1.9227
# Epoch 24/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.8702 - val_loss: 1.8606
# Epoch 25/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.8748 - val_loss: 2.0122
# Epoch 26/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.8571 - val_loss: 1.8837
# Epoch 27/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.8351 - val_loss: 1.7604
# Epoch 28/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7666 - val_loss: 1.8294
# Epoch 29/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7696 - val_loss: 2.1086
# Epoch 30/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7458 - val_loss: 1.7440
# Epoch 31/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7158 - val_loss: 1.8609
# Epoch 32/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7565 - val_loss: 1.8547
# Epoch 33/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7212 - val_loss: 1.6953
# Epoch 34/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7047 - val_loss: 1.8229
# Epoch 35/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.7300 - val_loss: 1.7566
# Epoch 36/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.6841 - val_loss: 2.1321
# Epoch 37/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.6846 - val_loss: 1.8630
# Epoch 38/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - loss: 1.7271 - val_loss: 1.7066
# Epoch 39/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.7105 - val_loss: 1.8640
# Epoch 40/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.7058 - val_loss: 1.8031
# Epoch 41/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - loss: 1.6812 - val_loss: 1.7421
# Epoch 42/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.7178 - val_loss: 1.6924
# Epoch 43/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.6725 - val_loss: 1.6910
# Epoch 44/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.6548 - val_loss: 1.9765
# Epoch 45/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.7084 - val_loss: 1.7886
# Epoch 46/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.6233 - val_loss: 1.7148
# Epoch 47/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - loss: 1.6766 - val_loss: 1.7044
# Epoch 48/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - loss: 1.6529 - val_loss: 1.7679
# Epoch 49/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - loss: 1.6813 - val_loss: 1.7847
# Epoch 50/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 1.6407 - val_loss: 1.8323
# Epoch 51/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.6351 - val_loss: 1.6859
# Epoch 52/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.6411 - val_loss: 1.8763
# Epoch 53/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.6548 - val_loss: 1.7263
# Epoch 54/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - loss: 1.6625 - val_loss: 1.7241
# Epoch 55/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - loss: 1.6547 - val_loss: 1.6911
# Epoch 56/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - loss: 1.6212 - val_loss: 1.7261
# Epoch 57/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - loss: 1.6190 - val_loss: 1.7207
# Epoch 58/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6949 - val_loss: 1.6683
# Epoch 59/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6355 - val_loss: 1.8124
# Epoch 60/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6963 - val_loss: 1.9270
# Epoch 61/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6735 - val_loss: 1.9025
# Epoch 62/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6573 - val_loss: 2.0031
# Epoch 63/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.5785 - val_loss: 1.6592
# Epoch 64/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6082 - val_loss: 1.6274
# Epoch 65/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 1.6140 - val_loss: 1.7132
# Epoch 66/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6406 - val_loss: 2.4131
# Epoch 67/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - loss: 1.6197 - val_loss: 1.8193
# Epoch 68/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - loss: 1.6498 - val_loss: 1.6381
# Epoch 69/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - loss: 1.6726 - val_loss: 1.8639
# Epoch 70/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - loss: 1.6188 - val_loss: 1.6163
# Epoch 71/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6013 - val_loss: 1.7202
# Epoch 72/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6189 - val_loss: 1.9790
# Epoch 73/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6521 - val_loss: 1.6830
# Epoch 74/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6124 - val_loss: 1.7413
# Epoch 75/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6850 - val_loss: 1.7352
# Epoch 76/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6157 - val_loss: 1.6282
# Epoch 77/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6443 - val_loss: 1.7186
# Epoch 78/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6608 - val_loss: 1.6674
# Epoch 79/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6041 - val_loss: 1.6476
# Epoch 80/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6198 - val_loss: 1.8155
# Epoch 81/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6281 - val_loss: 2.0463
# Epoch 82/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6356 - val_loss: 1.6684
# Epoch 83/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.5949 - val_loss: 1.8731
# Epoch 84/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6667 - val_loss: 1.7115
# Epoch 85/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6488 - val_loss: 1.7483
# Epoch 86/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.5773 - val_loss: 1.6529
# Epoch 87/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6187 - val_loss: 1.6519
# Epoch 88/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6074 - val_loss: 1.7103
# Epoch 89/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.5798 - val_loss: 1.6174
# Epoch 90/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6347 - val_loss: 1.6164
# Epoch 91/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6391 - val_loss: 1.6196
# Epoch 92/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6022 - val_loss: 1.8768
# Epoch 93/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6035 - val_loss: 1.6245
# Epoch 94/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6192 - val_loss: 1.6226
# Epoch 95/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6272 - val_loss: 1.6929
# Epoch 96/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.5834 - val_loss: 1.6343
# Epoch 97/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6031 - val_loss: 1.6409
# Epoch 98/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6172 - val_loss: 1.6774
# Epoch 99/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.6037 - val_loss: 1.6909
# Epoch 100/200
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - loss: 1.5949 - val_loss: 1.7949

# %% [markdown]
# # Model Evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from datetime import datetime

# Evaluate model
print(f"\nEvaluating model")
model = keras.models.load_model(checkpoint_filepath)
y_pred = model.predict(X_test, verbose=0)

# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title(f'\nTraining Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MAE)')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Evaluating model
# 2025-07-03 15:56:56.502749: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[7,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,3,40,40]{3,2,1,0}, f32[15,3,3,3]{3,2,1,0}, f32[15]{0}, f32[7,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-07-03 15:56:56.547086: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[7,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[7,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}

# %%
import sys
sys.path.append('../..')
from libs.plotting import *

print(y_pred.shape, Y_test_trimmed.shape)
print(f"RMSE: {rmse(y_pred, Y_test_trimmed):.2f}")
print(f"NRMSE: {nrmse(y_pred, Y_test_trimmed):.2f}")
print(f"MAE: {mae(y_pred, Y_test_trimmed):.2f}")
print(f"R2: {r2_score(Y_test_trimmed, y_pred):.2f}")
# Out:
# (2631, 1) (2631, 1)
# RMSE: 2.19
# NRMSE: 15.71
# MAE: 1.42
# R2: 0.88

# %%
sensor_names = ['Simi Valley - Cochran Street', 'Reseda', 'Santa Clarita', 'North Holywood', 'Los Angeles - N. Main Street', 'Compton', 'Long Beach Signal Hill', 'Glendora - Laurel']
comprehensive_frame_analysis(y_pred, Y_test, sensor_names)
# Out:
# Comprehensive frame analysis requires multi-frame predictions

# %% [markdown]
# # Plots

# %%
plt.plot(y_pred[1000:1168], label='pred')
plt.plot(Y_test_trimmed[1000:1168], label='actual')
plt.xlabel("Time (hourly)")
plt.ylabel("PM2.5 Concentrations")
plt.title("1 week snapshot of predictions")
plt.legend(loc="lower right")

# %%
plt.plot(y_pred[1000:1024], label='pred')
plt.plot(Y_test_trimmed[1000:1024], label='actual')
plt.xlabel("Time (hourly)")
plt.ylabel("PM2.5 Concentrations")
plt.title("1 day snapshot of predictions")
plt.legend(loc="lower right")

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_pred, label=f'pred', color='red')
plt.plot(Y_test_trimmed, label=f'actual', color='blue')
plt.title('Time Series (exact)')
plt.xlabel('Hour')
plt.ylabel('PM2.5')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd

series_pred = pd.Series(np.squeeze(y_pred))
series_test = pd.Series(np.squeeze(Y_test_trimmed))

window_size = 24 # daily average
smoothed_pred = series_pred.rolling(window=window_size).mean()
smoothed_test = series_test.rolling(window=window_size).mean()

plt.figure(figsize=(10, 6))
plt.plot(smoothed_pred, label=f'pred', color='red')
plt.plot(smoothed_test, label=f'actual', color='blue')
plt.title('Time Series with 24-hour Moving Average Smoothing')
plt.xlabel('Day')
plt.ylabel('PM2.5 Daily Average')
plt.legend()
plt.grid(True)
plt.show()

# %%
series_pred = pd.Series(np.squeeze(y_pred))
series_test = pd.Series(np.squeeze(Y_test_trimmed))

window_size = 168 # weekly average
smoothed_pred = series_pred.rolling(window=window_size).mean()
smoothed_test = series_test.rolling(window=window_size).mean()

plt.figure(figsize=(10, 6))
plt.plot(smoothed_pred, label=f'pred', color='red')
plt.plot(smoothed_test, label=f'actual', color='blue')
plt.title('Time Series with Weekly Moving Average Smoothing')
plt.xlabel('Week')
plt.ylabel('PM2.5 Weekly Average')
plt.legend()
plt.grid(True)
plt.show()

# %%
series_pred = pd.Series(np.squeeze(y_pred))
series_test = pd.Series(np.squeeze(Y_test_trimmed))

window_size = 720 # weekly average
smoothed_pred = series_pred.rolling(window=window_size).mean()
smoothed_test = series_test.rolling(window=window_size).mean()

plt.figure(figsize=(10, 6))
plt.plot(smoothed_pred, label=f'pred', color='red')
plt.plot(smoothed_test, label=f'actual', color='blue')
plt.title('Time Series with 30-day Moving Average Smoothing')
plt.xlabel('30-day')
plt.ylabel('PM2.5 30-day Average')
plt.legend()
plt.grid(True)
plt.show()
