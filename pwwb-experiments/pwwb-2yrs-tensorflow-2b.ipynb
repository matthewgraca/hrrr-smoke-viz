# %% [markdown]
# # Air Quality Prediction Experiment
#
# This notebook combines PWWB, AirNow, and HRRR datasets for air quality prediction using TF-Keras.
# Changes:
# - A lot of hard coding things like sensor names
# - Have another script handle ALL preprocessing; we just load the numpy files and stack them here
# - Removed scaled target data for simplicity
#
# Differences from original test:
# - Last notebook had overfitting issue; adding dropout rate of 80%.
# - Epochs 150 -> 100. Will increase if loss is trending well.
# - Reduced target sensors that were in the periphery outside of the LA metropolitan area

# %% [markdown]
# # Load data

# %%
# ========== EXPERIMENT CONFIGURATION ==========
# Change these variables to configure your experiment
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import os
from datetime import datetime

EXPERIMENT_NAME = "January 2022 to December 2024"
EXPERIMENT_DESCRIPTION = "January 2025 fire period with PWWB, Airnow, and HRRR data."
EXPERIMENT_ID = "two_years_pwwb_airnow_hrrr"

# Data parameters
START_DATE = "2022-12-01-00"
END_DATE = "2024-12-01-00"
TRAIN_SPLIT = 0.80  # 70% for training, 10% for val (will split later), leaving 20% for test.

# Model parameters
EPOCHS = 100
BATCH_SIZE = 16
WEIGHT_DECAY = 0.01

#all_channel_names = ['MAIAC_AOD', 'TROPOMI_NO2', 'METAR_Wind_U', 'METAR_Wind_V', 'AirNow_PM25', 'HRRR_COLMD']
all_channel_names = ['MAIAC_AOD', 'TROPOMI_NO2', 'METAR_Wind_U', 'METAR_Wind_V', 'AirNow_PM25']

print(f"Experiment: {EXPERIMENT_NAME}")
print(f"Description: {EXPERIMENT_DESCRIPTION}")
print(f"Date Range: {START_DATE} to {END_DATE}")
print(f"Train/Test Split: {TRAIN_SPLIT*100:.0f}%/{(1-TRAIN_SPLIT)*100:.0f}% (temporal)")
# Out:
# Experiment: January 2022 to December 2024
# Description: January 2025 fire period with PWWB, Airnow, and HRRR data.
# Date Range: 2022-12-01-00 to 2024-12-01-00
# Train/Test Split: 80%/20% (temporal)

# %%
# load: X_train_scaled, X_test_scaled (combined from np files), y_train, y_test.
test_files = ["MAIAC_AOD_X_test.npy", "TROPOMI_NO2_X_test.npy", "METAR_Wind_U_X_test.npy", "METAR_Wind_V_X_test.npy", "AirNow_PM25_X_test.npy"]
train_files = ["MAIAC_AOD_X_train.npy", "TROPOMI_NO2_X_train.npy", "METAR_Wind_U_X_train.npy", "METAR_Wind_V_X_train.npy", "AirNow_PM25_X_train.npy"]
X_train_scaled = np.stack([np.load(f"final_input_data/{file}") for file in train_files], axis=-1)
X_test_scaled = np.stack([np.load(f"final_input_data/{file}") for file in test_files], axis=-1)
Y_train = np.load("final_input_data/Y_train.npy")
Y_test = np.load("final_input_data/Y_test.npy")

# %%
# Debug cell to check channel names and data shapes
print("=== DEBUGGING CHANNEL INFORMATION ===")
print(f"Experiment name: {EXPERIMENT_NAME}")
print(f"X_train_scaled shape: {X_train_scaled.shape}")
print(f"Number of channels in data: {X_train_scaled.shape[4]}")
print(f"Number of channel names provided: {len(all_channel_names)}")
print(f"Channel names length matches data channels: {len(all_channel_names) == X_train_scaled.shape[4]}")
print()

print("Channel names provided:")
for i, name in enumerate(all_channel_names):
    print(f"  {i}: {name}")
print()

print("What the visualization function will use:")
n_channels = X_train_scaled.shape[4]
if all_channel_names is None or len(all_channel_names) != n_channels:
    effective_channel_names = [f"Channel {i}" for i in range(n_channels)]
    print("  Using GENERIC channel names (this is the problem!):")
else:
    effective_channel_names = all_channel_names
    print("  Using PROVIDED channel names:")

for i, name in enumerate(effective_channel_names):
    print(f"  {i}: {name}")
print()

print("=== DATA SAMPLE CHECK ===")
# Check what's actually in the first few channels
sample_idx = 42  # Use same sample as visualization
for c in range(min(3, n_channels)):  # Check first 3 channels
    data = X_train_scaled[sample_idx, 0, :, :, c]  # First frame
    print(f"Channel {c} ({effective_channel_names[c] if c < len(effective_channel_names) else 'Unknown'}):")
    print(f"  Min: {data.min():.6f}, Max: {data.max():.6f}, Mean: {data.mean():.6f}")
    print()
# Out:
# === DEBUGGING CHANNEL INFORMATION ===
# Experiment name: January 2022 to December 2024
# X_train_scaled shape: (14032, 5, 40, 40, 5)
# Number of channels in data: 5
# Number of channel names provided: 5
# Channel names length matches data channels: True
#
# Channel names provided:
#   0: MAIAC_AOD
#   1: TROPOMI_NO2
#   2: METAR_Wind_U
#   3: METAR_Wind_V
#   4: AirNow_PM25
#
# What the visualization function will use:
#   Using PROVIDED channel names:
#   0: MAIAC_AOD
#   1: TROPOMI_NO2
#   2: METAR_Wind_U
#   3: METAR_Wind_V
#   4: AirNow_PM25
#
# === DATA SAMPLE CHECK ===
# Channel 0 (MAIAC_AOD):
#   Min: -1.082072, Max: 1.538770, Mean: -0.268708
#
# Channel 1 (TROPOMI_NO2):
#   Min: -0.564229, Max: 0.134721, Mean: -0.139519
#
# Channel 2 (METAR_Wind_U):
#   Min: -2.473276, Max: -2.212808, Mean: -2.315924

# %%
# Function to visualize data from experiment
np.random.seed(42)
def visualize_experiment_data(X, Y, channel_names=None, sample_idx=None, experiment_name="Experiment"):
    """Visualize data from the experiment"""
    # Get a random sample if none provided
    if sample_idx is None:
        sample_idx = np.random.choice(range(len(X)), size=1)[0]
    
    # Get channel information
    n_channels = X.shape[4]
    n_frames = X.shape[1]
    
    # Use provided channel names or create default ones
    if channel_names is None or len(channel_names) != n_channels:
        channel_names = [f"Channel {i}" for i in range(n_channels)]
    
    # Create figure
    fig, axes = plt.subplots(n_channels, n_frames, figsize=(3*n_frames, 2*n_channels))
    if n_channels == 1:
        axes = axes.reshape(1, -1)
    
    # Plot each channel and frame
    for c in range(n_channels):
        channel_name = channel_names[c] if c < len(channel_names) else f"Channel {c}"
        
        for f in range(n_frames):
            ax = axes[c, f]
            data = X[sample_idx, f, :, :, c]
            
            im = ax.imshow(data)
            
            plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
            if f == 0:
                ax.set_ylabel(channel_name)
            ax.set_title(f"Frame {f+1}")
    
    # Set title
    plt.suptitle(f"{experiment_name}\nSample {sample_idx}")
    plt.tight_layout()
    plt.show()
    
    # Print target values
    if Y is not None:
        print(f"Target values: {Y[sample_idx]}")

# Run the visualization  
print(f"Visualizing data for {EXPERIMENT_NAME}...")
visualize_experiment_data(X_train_scaled, Y_train, channel_names=all_channel_names, experiment_name=EXPERIMENT_NAME)
# Out:
# Visualizing data for January 2022 to December 2024...
# Target values: [11.7 16.2 13.5  8.   9.3  8.6  0.   7.7]

# %% [markdown]
# # Tensorflow Model Definition

# %%
input_shape = X_train_scaled.shape[1:]  # (timesteps, height, width, channels)
output_size = Y_train.shape[1]

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv3D
from keras.layers import ConvLSTM2D
from keras.layers import BatchNormalization
from keras.layers import Convolution2D, MaxPooling3D, Flatten, Reshape
from keras.layers import TimeDistributed
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import InputLayer

tf.keras.backend.set_image_data_format('channels_last')

seq = Sequential()

seq.add(
    InputLayer(shape=input_shape)
)

seq.add(
    ConvLSTM2D(
            filters=15, 
            kernel_size=(3, 3),
            padding='same', 
            return_sequences=True
    )
)

seq.add(
    ConvLSTM2D(
        filters=30, 
        kernel_size=(3, 3),
        padding='same', 
        return_sequences=True
    )
)

seq.add(
    Conv3D(
        filters=15, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'    
    )
)

seq.add(
    Conv3D(
        filters=1, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'
    )
)

seq.add(Flatten())

seq.add(Dropout(rate=0.8))

seq.add(Dense(output_size,activation='relu'))

seq.compile(loss='mean_absolute_error', optimizer='adam')
seq.summary()
# Out:
# 2025-06-01 22:08:37.323574: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-01 22:08:37.331470: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748840917.341669   19896 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748840917.345052   19896 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-01 22:08:37.355209: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1748840918.851321   19896 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6350 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 5, 40, 40, 15)  │        10,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 5, 40, 40, 30)  │        48,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 5, 40, 40, 15)  │        12,165 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 5, 40, 40, 1)   │           406 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │        64,008 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 136,159 (531.87 KB)
#  Trainable params: 136,159 (531.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Model Training

# %%
print(f"\n==== Training Model for {EXPERIMENT_NAME} ====")
print(f"Training data shape: {X_train_scaled.shape}")
print(f"Target data shape: {Y_train.shape}")

history = seq.fit(X_train_scaled, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_split=0.2)

print(f"\n✓ Model training completed for {EXPERIMENT_NAME}!")
# Out:
# ==== Training Model for January 2022 to December 2024 ====
# Training data shape: (14032, 5, 40, 40, 5)
# Target data shape: (14032, 8)
# Epoch 1/100
# I0000 00:00:1748840923.899609   19988 service.cc:148] XLA service 0x63231478a900 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748840923.899632   19988 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2025-06-01 22:08:43.955771: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1748840924.224858   19988 cuda_dnn.cc:529] Loaded cuDNN version 90800
# 2025-06-01 22:08:44.685956: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[16,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-01 22:08:44.823128: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,5,40,40]{3,2,1,0}, f32[15,5,3,3]{3,2,1,0}, f32[15]{0}, f32[16,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
#   5/702 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - loss: 8.3423
# I0000 00:00:1748840926.540641   19988 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 701/702 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.5126
# 2025-06-01 22:09:07.047984: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[9,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[9,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[9,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-01 22:09:07.167564: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[9,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[9,5,40,40]{3,2,1,0}, f32[15,5,3,3]{3,2,1,0}, f32[15]{0}, f32[9,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.5117
# 2025-06-01 22:09:11.184091: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[7,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,5,40,40]{3,2,1,0}, f32[15,5,3,3]{3,2,1,0}, f32[15]{0}, f32[7,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-01 22:09:11.226638: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[7,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[7,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 30s 36ms/step - loss: 3.5109 - val_loss: 2.5529
# Epoch 2/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 2.3584 - val_loss: 2.4727
# Epoch 3/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 2.1875 - val_loss: 2.3374
# Epoch 4/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 2.0648 - val_loss: 2.1908
# Epoch 5/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.9671 - val_loss: 2.1646
# Epoch 6/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.8883 - val_loss: 2.0247
# Epoch 7/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.8562 - val_loss: 2.0117
# Epoch 8/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.8275 - val_loss: 1.9495
# Epoch 9/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.8201 - val_loss: 2.0564
# Epoch 10/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.7805 - val_loss: 1.9264
# Epoch 11/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.7789 - val_loss: 1.9346
# Epoch 12/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.7777 - val_loss: 1.8965
# Epoch 13/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.7664 - val_loss: 1.8720
# Epoch 14/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.7258 - val_loss: 1.9469
# Epoch 15/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.7443 - val_loss: 1.9244
# Epoch 16/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.7018 - val_loss: 1.9058
# Epoch 17/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.6882 - val_loss: 1.9512
# Epoch 18/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.7190 - val_loss: 1.9296
# Epoch 19/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.7017 - val_loss: 1.8787
# Epoch 20/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.6873 - val_loss: 1.8493
# Epoch 21/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6988 - val_loss: 1.9039
# Epoch 22/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6674 - val_loss: 1.9205
# Epoch 23/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6620 - val_loss: 1.8972
# Epoch 24/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.6444 - val_loss: 1.8738
# Epoch 25/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - loss: 1.6759 - val_loss: 1.9301
# Epoch 26/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6744 - val_loss: 1.8660
# Epoch 27/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6554 - val_loss: 2.0191
# Epoch 28/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6711 - val_loss: 1.8680
# Epoch 29/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6737 - val_loss: 1.9099
# Epoch 30/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6613 - val_loss: 1.8237
# Epoch 31/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6417 - val_loss: 1.9090
# Epoch 32/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - loss: 1.6357 - val_loss: 1.9058
# Epoch 33/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.6338 - val_loss: 1.9125
# Epoch 34/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6386 - val_loss: 1.9032
# Epoch 35/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6050 - val_loss: 1.8946
# Epoch 36/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5908 - val_loss: 1.9465
# Epoch 37/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6127 - val_loss: 1.9234
# Epoch 38/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6069 - val_loss: 1.9475
# Epoch 39/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6275 - val_loss: 1.8587
# Epoch 40/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6006 - val_loss: 1.9267
# Epoch 41/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.6038 - val_loss: 1.8650
# Epoch 42/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5916 - val_loss: 1.9703
# Epoch 43/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5968 - val_loss: 1.9029
# Epoch 44/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5796 - val_loss: 1.9617
# Epoch 45/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5795 - val_loss: 1.9080
# Epoch 46/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5770 - val_loss: 1.9460
# Epoch 47/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5869 - val_loss: 1.8793
# Epoch 48/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5710 - val_loss: 1.9359
# Epoch 49/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5847 - val_loss: 1.9587
# Epoch 50/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5735 - val_loss: 2.0083
# Epoch 51/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5652 - val_loss: 1.8987
# Epoch 52/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5625 - val_loss: 1.9216
# Epoch 53/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5876 - val_loss: 1.9412
# Epoch 54/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5530 - val_loss: 2.0370
# Epoch 55/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5581 - val_loss: 1.9334
# Epoch 56/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5661 - val_loss: 1.9821
# Epoch 57/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5345 - val_loss: 1.9754
# Epoch 58/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5485 - val_loss: 1.9644
# Epoch 59/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5424 - val_loss: 1.9309
# Epoch 60/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5457 - val_loss: 1.9796
# Epoch 61/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5428 - val_loss: 1.9675
# Epoch 62/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5386 - val_loss: 1.9230
# Epoch 63/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 1.5458 - val_loss: 1.9240
# Epoch 64/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5336 - val_loss: 1.9127
# Epoch 65/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5317 - val_loss: 1.9005
# Epoch 66/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5332 - val_loss: 1.9714
# Epoch 67/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5409 - val_loss: 2.0219
# Epoch 68/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5242 - val_loss: 1.9423
# Epoch 69/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5584 - val_loss: 1.9653
# Epoch 70/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5125 - val_loss: 1.9046
# Epoch 71/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5251 - val_loss: 1.9506
# Epoch 72/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5290 - val_loss: 1.8821
# Epoch 73/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5127 - val_loss: 1.8892
# Epoch 74/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5128 - val_loss: 1.8729
# Epoch 75/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5093 - val_loss: 2.0470
# Epoch 76/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4975 - val_loss: 1.9267
# Epoch 77/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5033 - val_loss: 1.9565
# Epoch 78/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5087 - val_loss: 1.8786
# Epoch 79/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.5165 - val_loss: 1.8804
# Epoch 80/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4891 - val_loss: 1.8974
# Epoch 81/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4980 - val_loss: 1.9350
# Epoch 82/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4951 - val_loss: 1.9490
# Epoch 83/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4848 - val_loss: 1.9137
# Epoch 84/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4896 - val_loss: 2.0219
# Epoch 85/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4872 - val_loss: 1.9760
# Epoch 86/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4890 - val_loss: 1.9384
# Epoch 87/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4762 - val_loss: 1.9449
# Epoch 88/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4788 - val_loss: 1.8907
# Epoch 89/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4899 - val_loss: 1.9792
# Epoch 90/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4960 - val_loss: 2.0011
# Epoch 91/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4876 - val_loss: 1.9769
# Epoch 92/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4741 - val_loss: 1.8903
# Epoch 93/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4526 - val_loss: 1.9089
# Epoch 94/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4788 - val_loss: 1.9403
# Epoch 95/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4758 - val_loss: 1.9377
# Epoch 96/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4742 - val_loss: 1.9962
# Epoch 97/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4762 - val_loss: 1.9621
# Epoch 98/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4550 - val_loss: 1.9275
# Epoch 99/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4676 - val_loss: 1.9693
# Epoch 100/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 1.4417 - val_loss: 1.8653
#
# ✓ Model training completed for January 2022 to December 2024!

# %% [markdown]
# # Model Evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import os
from datetime import datetime

# Create output directory for results
output_dir = f"experiment_output/{EXPERIMENT_ID}"
os.makedirs(output_dir, exist_ok=True)

# Evaluate model
print(f"\nEvaluating model for {EXPERIMENT_NAME}...")
y_pred = seq.predict(X_test_scaled, verbose=0)

# Calculate metrics on real scale
mae_real = mean_absolute_error(Y_test, y_pred)
rmse_real = np.sqrt(mean_squared_error(Y_test, y_pred))
r2_real = r2_score(Y_test, y_pred)

print(f"\nFinal Results for {EXPERIMENT_NAME} (Real PM2.5 Scale):")
print(f"Mean Absolute Error: {mae_real:.4f} μg/m³")
print(f"Root Mean Squared Error: {rmse_real:.4f} μg/m³")
print(f"R² Score: {r2_real:.4f}")


# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title(f'{EXPERIMENT_NAME}\nTraining Loss (Scaled Targets)')
plt.xlabel('Epoch')
plt.ylabel('Loss (MAE)')
plt.grid(True, alpha=0.3)
plt.show()

# Save results (save both scaled and real versions)
results_dir = os.path.join(output_dir, "results")
os.makedirs(results_dir, exist_ok=True)

# Save real scale results for analysis
np.save(os.path.join(results_dir, "y_pred.npy"), y_pred)
np.save(os.path.join(results_dir, "Y_test.npy"), Y_test)

# Save model and scaler
seq.save(os.path.join(results_dir, "model.keras"))

print(f"\n✓ Evaluation completed for {EXPERIMENT_NAME}")
print(f"Results saved to: {results_dir}")
# Out:
# Evaluating model for January 2022 to December 2024...
# 2025-06-01 22:44:25.214762: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,5,40,40]{3,2,1,0}, f32[15,5,3,3]{3,2,1,0}, f32[15]{0}, f32[32,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-01 22:44:25.270972: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[32,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-01 22:44:27.979400: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[20,15,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,5,40,40]{3,2,1,0}, f32[15,5,3,3]{3,2,1,0}, f32[15]{0}, f32[20,15,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-06-01 22:44:28.032151: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[20,30,40,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,15,40,40]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[20,30,40,40]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# Final Results for January 2022 to December 2024 (Real PM2.5 Scale):
# Mean Absolute Error: 1.8873 μg/m³
# Root Mean Squared Error: 3.2981 μg/m³
# R² Score: 0.7205
# ✓ Evaluation completed for January 2022 to December 2024
# Results saved to: experiment_output/two_years_pwwb_airnow_hrrr/results

# %% [markdown]
# # Detailed Analysis

# %%
print(f"\nDetailed analysis for {EXPERIMENT_NAME}:")
print(f"Description: {EXPERIMENT_DESCRIPTION}")
print(f"Date range: {START_DATE} to {END_DATE}")
print(f"Temporal split: {TRAIN_SPLIT*100:.0f}%/{(1-TRAIN_SPLIT)*100:.0f}%")
print(f"Total sensors: {Y_test.shape[1]}")
# Out:
# Detailed analysis for January 2022 to December 2024:
# Description: January 2025 fire period with PWWB, Airnow, and HRRR data.
# Date range: 2022-12-01-00 to 2024-12-01-00
# Temporal split: 80%/20%
# Total sensors: 8

# %%
import matplotlib.pyplot as plt

# Check target distribution
Y_flat = Y_train.flatten()
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(Y_flat, bins=50, alpha=0.7)
plt.title('Scaled Target Distribution')
plt.xlabel('Scaled Value')

plt.subplot(1, 2, 2)
plt.hist(Y_flat[Y_flat < 2], bins=50, alpha=0.7)  # Zoom in on normal range
plt.title('Scaled Targets (< 2.0)')
plt.xlabel('Scaled Value')

plt.tight_layout()
plt.show()

print(f"Percentage of targets > 5.0: {(Y_flat > 5.0).mean()*100:.1f}%")
print(f"Percentage of targets > 2.0: {(Y_flat > 2.0).mean()*100:.1f}%")
# Out:
# Percentage of targets > 5.0: 73.3%
# Percentage of targets > 2.0: 89.8%

# %%
print("Original targets:")
print(f"Y_train range: {Y_train.min():.3f} to {Y_train.max():.3f}")
# Out:
# Original targets:
# Y_train range: 0.000 to 358.900

# %%
import sys
sys.path.append("..")

from libs.plotting import (
    plot_prediction_comparison,
    plot_scatter_comparison,
    plot_error_by_sensor,
    plot_time_series_comparison,
    plot_input_frames,
    print_metrics
)

# Get sensor names
sensor_names = [
    'Simi Valley - Cochran Street', 'Reseda', 'Santa Clarita', 'North Holywood', 
    'Los Angeles - N. Main Street', 'Compton', 'Long Beach Signal Hill', 'Glendora - Laurel'
]

print(f"\nSensors in {EXPERIMENT_NAME}: {sensor_names}")

print("\n1. Plotting prediction comparison...")
plot_prediction_comparison(y_pred, Y_test, sensor_names, sample_idx=8)

print("\n2. Plotting scatter comparison...")
plot_scatter_comparison(y_pred, Y_test)

print("\n3. Plotting error by sensor...")
plot_error_by_sensor(y_pred, Y_test, sensor_names)

print("\n4. Plotting time series comparison...")
plot_time_series_comparison(y_pred, Y_test, sensor_names)
    
print("\n5. Plotting time series with shifted predictions...")
plot_time_series_comparison(y_pred, Y_test, sensor_names, shift_pred=1)

print("\n6. Printing detailed metrics...")
print_metrics(y_pred, Y_test, sensor_names)
# Out:
# Sensors in January 2022 to December 2024: ['Simi Valley - Cochran Street', 'Reseda', 'Santa Clarita', 'North Holywood', 'Los Angeles - N. Main Street', 'Compton', 'Long Beach Signal Hill', 'Glendora - Laurel']
#
# 1. Plotting prediction comparison...
# 2. Plotting scatter comparison...
# 3. Plotting error by sensor...
# 4. Plotting time series comparison...
# 5. Plotting time series with shifted predictions...
# 6. Printing detailed metrics...
# RESULTS
# ---------------------------------------------------------------------------
# All Days All Locations - y_pred vs y_test Raw RMSE: 3.30
# All Days All Locations - y_pred vs y_test RMSE Percent Error of Mean: 31.31%
#
# RESULTS BY FRAME
# ---------------------------------------------------------------------------
# Frame 1 (Hour 1) All Locations - Raw RMSE: 1.42
# Frame 1 (Hour 1) All Locations - RMSE Percent Error of Mean: 13.47%
#
# Frame 2 (Hour 2) All Locations - Raw RMSE: 1.40
# Frame 2 (Hour 2) All Locations - RMSE Percent Error of Mean: 13.26%
#
# Frame 3 (Hour 3) All Locations - Raw RMSE: 1.69
# Frame 3 (Hour 3) All Locations - RMSE Percent Error of Mean: 16.25%
#
# Frame 4 (Hour 4) All Locations - Raw RMSE: 1.17
# Frame 4 (Hour 4) All Locations - RMSE Percent Error of Mean: 12.00%
#
# Frame 5 (Hour 5) All Locations - Raw RMSE: 1.38
# Frame 5 (Hour 5) All Locations - RMSE Percent Error of Mean: 14.18%
#
# Frame 6 (Hour 6) All Locations - Raw RMSE: 0.68
# Frame 6 (Hour 6) All Locations - RMSE Percent Error of Mean: 7.19%
#
# Frame 7 (Hour 7) All Locations - Raw RMSE: 1.77
# Frame 7 (Hour 7) All Locations - RMSE Percent Error of Mean: 18.50%
#
# Frame 8 (Hour 8) All Locations - Raw RMSE: 1.68
# Frame 8 (Hour 8) All Locations - RMSE Percent Error of Mean: 16.76%
#
# Frame 9 (Hour 9) All Locations - Raw RMSE: 1.44
# Frame 9 (Hour 9) All Locations - RMSE Percent Error of Mean: 13.66%
#
# Frame 10 (Hour 10) All Locations - Raw RMSE: 1.19
# Frame 10 (Hour 10) All Locations - RMSE Percent Error of Mean: 10.91%
#
# Frame 11 (Hour 11) All Locations - Raw RMSE: 1.18
# Frame 11 (Hour 11) All Locations - RMSE Percent Error of Mean: 11.00%
#
# Frame 12 (Hour 12) All Locations - Raw RMSE: 1.35
# Frame 12 (Hour 12) All Locations - RMSE Percent Error of Mean: 12.81%
#
# Frame 13 (Hour 13) All Locations - Raw RMSE: 2.34
# Frame 13 (Hour 13) All Locations - RMSE Percent Error of Mean: 20.89%
#
# Frame 14 (Hour 14) All Locations - Raw RMSE: 1.63
# Frame 14 (Hour 14) All Locations - RMSE Percent Error of Mean: 15.44%
#
# Frame 15 (Hour 15) All Locations - Raw RMSE: 1.94
# Frame 15 (Hour 15) All Locations - RMSE Percent Error of Mean: 17.59%
#
# Frame 16 (Hour 16) All Locations - Raw RMSE: 2.06
# Frame 16 (Hour 16) All Locations - RMSE Percent Error of Mean: 17.75%
#
# Frame 17 (Hour 17) All Locations - Raw RMSE: 2.13
# Frame 17 (Hour 17) All Locations - RMSE Percent Error of Mean: 16.90%
#
# Frame 18 (Hour 18) All Locations - Raw RMSE: 3.81
# Frame 18 (Hour 18) All Locations - RMSE Percent Error of Mean: 26.27%
#
# Frame 19 (Hour 19) All Locations - Raw RMSE: 2.05
# Frame 19 (Hour 19) All Locations - RMSE Percent Error of Mean: 13.11%
#
# Frame 20 (Hour 20) All Locations - Raw RMSE: 1.11
# Frame 20 (Hour 20) All Locations - RMSE Percent Error of Mean: 6.97%
#
# Frame 21 (Hour 21) All Locations - Raw RMSE: 2.32
# Frame 21 (Hour 21) All Locations - RMSE Percent Error of Mean: 14.08%
#
# Frame 22 (Hour 22) All Locations - Raw RMSE: 1.46
# Frame 22 (Hour 22) All Locations - RMSE Percent Error of Mean: 8.91%
#
# Frame 23 (Hour 23) All Locations - Raw RMSE: 2.35
# Frame 23 (Hour 23) All Locations - RMSE Percent Error of Mean: 15.52%
#
# Frame 24 (Hour 24) All Locations - Raw RMSE: 2.79
# Frame 24 (Hour 24) All Locations - RMSE Percent Error of Mean: 19.86%
#
# Frame 25 (Hour 25) All Locations - Raw RMSE: 1.98
# Frame 25 (Hour 25) All Locations - RMSE Percent Error of Mean: 14.67%
#
# Frame 26 (Hour 26) All Locations - Raw RMSE: 1.88
# Frame 26 (Hour 26) All Locations - RMSE Percent Error of Mean: 14.36%
#
# Frame 27 (Hour 27) All Locations - Raw RMSE: 1.77
# Frame 27 (Hour 27) All Locations - RMSE Percent Error of Mean: 14.24%
#
# Frame 49 (Hour 49) All Locations - Raw RMSE: 1.27
# Frame 49 (Hour 49) All Locations - RMSE Percent Error of Mean: 7.12%
#
# Frame 50 (Hour 50) All Locations - Raw RMSE: 2.32
# Frame 50 (Hour 50) All Locations - RMSE Percent Error of Mean: 12.79%
#
# Frame 51 (Hour 51) All Locations - Raw RMSE: 2.26
# Frame 51 (Hour 51) All Locations - RMSE Percent Error of Mean: 12.81%
#
# Frame 52 (Hour 52) All Locations - Raw RMSE: 2.44
# Frame 52 (Hour 52) All Locations - RMSE Percent Error of Mean: 15.93%
#
# Frame 53 (Hour 53) All Locations - Raw RMSE: 1.62
# Frame 53 (Hour 53) All Locations - RMSE Percent Error of Mean: 11.69%
#
# Frame 54 (Hour 54) All Locations - Raw RMSE: 1.20
# Frame 54 (Hour 54) All Locations - RMSE Percent Error of Mean: 9.63%
#
# Frame 55 (Hour 55) All Locations - Raw RMSE: 1.05
# Frame 55 (Hour 55) All Locations - RMSE Percent Error of Mean: 9.04%
#
# Frame 56 (Hour 56) All Locations - Raw RMSE: 1.40
# Frame 56 (Hour 56) All Locations - RMSE Percent Error of Mean: 12.46%
#
# Frame 57 (Hour 57) All Locations - Raw RMSE: 1.79
# Frame 57 (Hour 57) All Locations - RMSE Percent Error of Mean: 16.00%
#
# Frame 58 (Hour 58) All Locations - Raw RMSE: 1.15
# Frame 58 (Hour 58) All Locations - RMSE Percent Error of Mean: 10.02%
#
# Frame 59 (Hour 59) All Locations - Raw RMSE: 1.23
# Frame 59 (Hour 59) All Locations - RMSE Percent Error of Mean: 10.56%
#
# Frame 60 (Hour 60) All Locations - Raw RMSE: 1.06
# Frame 60 (Hour 60) All Locations - RMSE Percent Error of Mean: 9.28%
#
# Frame 61 (Hour 61) All Locations - Raw RMSE: 1.48
# Frame 61 (Hour 61) All Locations - RMSE Percent Error of Mean: 12.85%
#
# Frame 62 (Hour 62) All Locations - Raw RMSE: 1.96
# Frame 62 (Hour 62) All Locations - RMSE Percent Error of Mean: 15.49%
#
# Frame 63 (Hour 63) All Locations - Raw RMSE: 1.88
# Frame 63 (Hour 63) All Locations - RMSE Percent Error of Mean: 15.00%
#
# Frame 64 (Hour 64) All Locations - Raw RMSE: 1.18
# Frame 64 (Hour 64) All Locations - RMSE Percent Error of Mean: 9.33%
#
# Frame 65 (Hour 65) All Locations - Raw RMSE: 1.50
# Frame 65 (Hour 65) All Locations - RMSE Percent Error of Mean: 11.55%
#
# Frame 66 (Hour 66) All Locations - Raw RMSE: 1.43
# Frame 66 (Hour 66) All Locations - RMSE Percent Error of Mean: 10.28%
#
# Frame 67 (Hour 67) All Locations - Raw RMSE: 1.24
# Frame 67 (Hour 67) All Locations - RMSE Percent Error of Mean: 8.14%
#
# Frame 68 (Hour 68) All Locations - Raw RMSE: 2.09
# Frame 68 (Hour 68) All Locations - RMSE Percent Error of Mean: 12.83%
#
# Frame 69 (Hour 69) All Locations - Raw RMSE: 6.19
# Frame 69 (Hour 69) All Locations - RMSE Percent Error of Mean: 39.25%
#
# Frame 3396 (Hour 3396) All Locations - Raw RMSE: 1.77
# Frame 3396 (Hour 3396) All Locations - RMSE Percent Error of Mean: 12.01%
#
# Frame 3397 (Hour 3397) All Locations - Raw RMSE: 2.91
# Frame 3397 (Hour 3397) All Locations - RMSE Percent Error of Mean: 20.65%
#
# Frame 3398 (Hour 3398) All Locations - Raw RMSE: 4.39
# Frame 3398 (Hour 3398) All Locations - RMSE Percent Error of Mean: 33.16%
#
# Frame 3399 (Hour 3399) All Locations - Raw RMSE: 4.43
# Frame 3399 (Hour 3399) All Locations - RMSE Percent Error of Mean: 36.09%
#
# Frame 3400 (Hour 3400) All Locations - Raw RMSE: 2.10
# Frame 3400 (Hour 3400) All Locations - RMSE Percent Error of Mean: 18.40%
#
# Frame 3401 (Hour 3401) All Locations - Raw RMSE: 1.73
# Frame 3401 (Hour 3401) All Locations - RMSE Percent Error of Mean: 15.45%
#
# Frame 3402 (Hour 3402) All Locations - Raw RMSE: 2.70
# Frame 3402 (Hour 3402) All Locations - RMSE Percent Error of Mean: 23.92%
#
# Frame 3403 (Hour 3403) All Locations - Raw RMSE: 0.92
# Frame 3403 (Hour 3403) All Locations - RMSE Percent Error of Mean: 8.28%
#
# Frame 3404 (Hour 3404) All Locations - Raw RMSE: 3.01
# Frame 3404 (Hour 3404) All Locations - RMSE Percent Error of Mean: 28.97%
#
# Frame 3405 (Hour 3405) All Locations - Raw RMSE: 2.55
# Frame 3405 (Hour 3405) All Locations - RMSE Percent Error of Mean: 24.78%
#
# Frame 3406 (Hour 3406) All Locations - Raw RMSE: 1.93
# Frame 3406 (Hour 3406) All Locations - RMSE Percent Error of Mean: 21.46%
#
# Frame 3407 (Hour 3407) All Locations - Raw RMSE: 2.22
# Frame 3407 (Hour 3407) All Locations - RMSE Percent Error of Mean: 31.26%
#
# Frame 3408 (Hour 3408) All Locations - Raw RMSE: 2.46
# Frame 3408 (Hour 3408) All Locations - RMSE Percent Error of Mean: 47.10%
#
# Frame 3409 (Hour 3409) All Locations - Raw RMSE: 1.49
# Frame 3409 (Hour 3409) All Locations - RMSE Percent Error of Mean: 37.80%
#
# Frame 3410 (Hour 3410) All Locations - Raw RMSE: 1.05
# Frame 3410 (Hour 3410) All Locations - RMSE Percent Error of Mean: 34.05%
#
# Frame 3411 (Hour 3411) All Locations - Raw RMSE: 1.20
# Frame 3411 (Hour 3411) All Locations - RMSE Percent Error of Mean: 60.47%
#
# Frame 3412 (Hour 3412) All Locations - Raw RMSE: 1.43
# Frame 3412 (Hour 3412) All Locations - RMSE Percent Error of Mean: 78.25%
#
# Frame 3413 (Hour 3413) All Locations - Raw RMSE: 1.39
# Frame 3413 (Hour 3413) All Locations - RMSE Percent Error of Mean: 49.24%
#
# Frame 3414 (Hour 3414) All Locations - Raw RMSE: 1.02
# Frame 3414 (Hour 3414) All Locations - RMSE Percent Error of Mean: 27.92%
#
# Frame 3415 (Hour 3415) All Locations - Raw RMSE: 1.19
# Frame 3415 (Hour 3415) All Locations - RMSE Percent Error of Mean: 25.26%
#
# Frame 3416 (Hour 3416) All Locations - Raw RMSE: 1.53
# Frame 3416 (Hour 3416) All Locations - RMSE Percent Error of Mean: 30.72%
#
# Frame 3417 (Hour 3417) All Locations - Raw RMSE: 0.80
# Frame 3417 (Hour 3417) All Locations - RMSE Percent Error of Mean: 15.62%
#
# Frame 3418 (Hour 3418) All Locations - Raw RMSE: 0.76
# Frame 3418 (Hour 3418) All Locations - RMSE Percent Error of Mean: 14.60%
#
# Frame 3419 (Hour 3419) All Locations - Raw RMSE: 1.13
# Frame 3419 (Hour 3419) All Locations - RMSE Percent Error of Mean: 20.61%
#
# Frame 3420 (Hour 3420) All Locations - Raw RMSE: 0.68
# Frame 3420 (Hour 3420) All Locations - RMSE Percent Error of Mean: 11.85%
#
# Frame 3421 (Hour 3421) All Locations - Raw RMSE: 1.24
# Frame 3421 (Hour 3421) All Locations - RMSE Percent Error of Mean: 21.26%
#
# Frame 3422 (Hour 3422) All Locations - Raw RMSE: 1.75
# Frame 3422 (Hour 3422) All Locations - RMSE Percent Error of Mean: 27.29%
#
# Frame 3423 (Hour 3423) All Locations - Raw RMSE: 2.27
# Frame 3423 (Hour 3423) All Locations - RMSE Percent Error of Mean: 42.11%
#
# Frame 3424 (Hour 3424) All Locations - Raw RMSE: 1.72
# Frame 3424 (Hour 3424) All Locations - RMSE Percent Error of Mean: 35.03%
#
# Frame 3425 (Hour 3425) All Locations - Raw RMSE: 1.34
# Frame 3425 (Hour 3425) All Locations - RMSE Percent Error of Mean: 26.75%
#
# Frame 3426 (Hour 3426) All Locations - Raw RMSE: 1.07
# Frame 3426 (Hour 3426) All Locations - RMSE Percent Error of Mean: 20.55%
#
# Frame 3427 (Hour 3427) All Locations - Raw RMSE: 1.53
# Frame 3427 (Hour 3427) All Locations - RMSE Percent Error of Mean: 28.54%
#
# Frame 3428 (Hour 3428) All Locations - Raw RMSE: 1.03
# Frame 3428 (Hour 3428) All Locations - RMSE Percent Error of Mean: 17.55%
#
# Frame 3429 (Hour 3429) All Locations - Raw RMSE: 1.37
# Frame 3429 (Hour 3429) All Locations - RMSE Percent Error of Mean: 22.74%
#
# Frame 3430 (Hour 3430) All Locations - Raw RMSE: 1.50
# Frame 3430 (Hour 3430) All Locations - RMSE Percent Error of Mean: 25.87%
#
# Frame 3431 (Hour 3431) All Locations - Raw RMSE: 1.24
# Frame 3431 (Hour 3431) All Locations - RMSE Percent Error of Mean: 24.58%
#
# Frame 3432 (Hour 3432) All Locations - Raw RMSE: 1.17
# Frame 3432 (Hour 3432) All Locations - RMSE Percent Error of Mean: 27.09%
#
# Frame 3433 (Hour 3433) All Locations - Raw RMSE: 1.84
# Frame 3433 (Hour 3433) All Locations - RMSE Percent Error of Mean: 48.79%
#
# Frame 3434 (Hour 3434) All Locations - Raw RMSE: 1.19
# Frame 3434 (Hour 3434) All Locations - RMSE Percent Error of Mean: 27.98%
#
# Frame 3435 (Hour 3435) All Locations - Raw RMSE: 1.50
# Frame 3435 (Hour 3435) All Locations - RMSE Percent Error of Mean: 30.34%
#
# Frame 3436 (Hour 3436) All Locations - Raw RMSE: 1.54
# Frame 3436 (Hour 3436) All Locations - RMSE Percent Error of Mean: 29.05%
#
# Frame 3437 (Hour 3437) All Locations - Raw RMSE: 1.66
# Frame 3437 (Hour 3437) All Locations - RMSE Percent Error of Mean: 26.53%
#
# Frame 3438 (Hour 3438) All Locations - Raw RMSE: 1.47
# Frame 3438 (Hour 3438) All Locations - RMSE Percent Error of Mean: 18.78%
#
# Frame 3439 (Hour 3439) All Locations - Raw RMSE: 1.30
# Frame 3439 (Hour 3439) All Locations - RMSE Percent Error of Mean: 13.88%
#
# Frame 3440 (Hour 3440) All Locations - Raw RMSE: 2.49
# Frame 3440 (Hour 3440) All Locations - RMSE Percent Error of Mean: 23.01%
#
# Frame 3441 (Hour 3441) All Locations - Raw RMSE: 1.87
# Frame 3441 (Hour 3441) All Locations - RMSE Percent Error of Mean: 16.62%
#
# Frame 3442 (Hour 3442) All Locations - Raw RMSE: 2.22
# Frame 3442 (Hour 3442) All Locations - RMSE Percent Error of Mean: 18.54%
#
# Frame 3443 (Hour 3443) All Locations - Raw RMSE: 1.59
# Frame 3443 (Hour 3443) All Locations - RMSE Percent Error of Mean: 13.20%
#
# Frame 3444 (Hour 3444) All Locations - Raw RMSE: 2.28
# Frame 3444 (Hour 3444) All Locations - RMSE Percent Error of Mean: 20.91%
#
# Frame 3445 (Hour 3445) All Locations - Raw RMSE: 2.04
# Frame 3445 (Hour 3445) All Locations - RMSE Percent Error of Mean: 18.85%
#
# Frame 3446 (Hour 3446) All Locations - Raw RMSE: 1.11
# Frame 3446 (Hour 3446) All Locations - RMSE Percent Error of Mean: 10.82%
#
# Frame 3447 (Hour 3447) All Locations - Raw RMSE: 1.65
# Frame 3447 (Hour 3447) All Locations - RMSE Percent Error of Mean: 15.90%
#
# Frame 3448 (Hour 3448) All Locations - Raw RMSE: 2.14
# Frame 3448 (Hour 3448) All Locations - RMSE Percent Error of Mean: 20.95%
#
# Frame 3449 (Hour 3449) All Locations - Raw RMSE: 1.84
# Frame 3449 (Hour 3449) All Locations - RMSE Percent Error of Mean: 19.58%
#
# Frame 3450 (Hour 3450) All Locations - Raw RMSE: 1.89
# Frame 3450 (Hour 3450) All Locations - RMSE Percent Error of Mean: 20.04%
#
# Frame 3451 (Hour 3451) All Locations - Raw RMSE: 1.80
# Frame 3451 (Hour 3451) All Locations - RMSE Percent Error of Mean: 19.44%
#
# Frame 3452 (Hour 3452) All Locations - Raw RMSE: 0.87
# Frame 3452 (Hour 3452) All Locations - RMSE Percent Error of Mean: 10.45%
#
# Frame 3453 (Hour 3453) All Locations - Raw RMSE: 1.65
# Frame 3453 (Hour 3453) All Locations - RMSE Percent Error of Mean: 24.25%
#
# Frame 3454 (Hour 3454) All Locations - Raw RMSE: 2.20
# Frame 3454 (Hour 3454) All Locations - RMSE Percent Error of Mean: 35.10%
#
# Frame 3455 (Hour 3455) All Locations - Raw RMSE: 1.25
# Frame 3455 (Hour 3455) All Locations - RMSE Percent Error of Mean: 23.49%
#
# Frame 3456 (Hour 3456) All Locations - Raw RMSE: 1.04
# Frame 3456 (Hour 3456) All Locations - RMSE Percent Error of Mean: 26.30%
#
# Frame 3457 (Hour 3457) All Locations - Raw RMSE: 1.00
# Frame 3457 (Hour 3457) All Locations - RMSE Percent Error of Mean: 34.10%
#
# Frame 3458 (Hour 3458) All Locations - Raw RMSE: 1.62
# Frame 3458 (Hour 3458) All Locations - RMSE Percent Error of Mean: 67.38%
#
# Frame 3459 (Hour 3459) All Locations - Raw RMSE: 1.28
# Frame 3459 (Hour 3459) All Locations - RMSE Percent Error of Mean: 54.40%
#
# Frame 3460 (Hour 3460) All Locations - Raw RMSE: 1.69
# Frame 3460 (Hour 3460) All Locations - RMSE Percent Error of Mean: 63.05%
#
# Frame 3461 (Hour 3461) All Locations - Raw RMSE: 1.79
# Frame 3461 (Hour 3461) All Locations - RMSE Percent Error of Mean: 48.14%
#
# Frame 3462 (Hour 3462) All Locations - Raw RMSE: 5.28
# Frame 3462 (Hour 3462) All Locations - RMSE Percent Error of Mean: 74.04%
#
# Frame 3463 (Hour 3463) All Locations - Raw RMSE: 5.58
# Frame 3463 (Hour 3463) All Locations - RMSE Percent Error of Mean: 58.70%
#
# Frame 3464 (Hour 3464) All Locations - Raw RMSE: 2.77
# Frame 3464 (Hour 3464) All Locations - RMSE Percent Error of Mean: 31.74%
#
# Frame 3465 (Hour 3465) All Locations - Raw RMSE: 3.70
# Frame 3465 (Hour 3465) All Locations - RMSE Percent Error of Mean: 40.93%
#
# Frame 3466 (Hour 3466) All Locations - Raw RMSE: 3.33
# Frame 3466 (Hour 3466) All Locations - RMSE Percent Error of Mean: 35.06%
#
# Frame 3467 (Hour 3467) All Locations - Raw RMSE: 4.63
# Frame 3467 (Hour 3467) All Locations - RMSE Percent Error of Mean: 42.25%
#
# Frame 3468 (Hour 3468) All Locations - Raw RMSE: 6.32
# Frame 3468 (Hour 3468) All Locations - RMSE Percent Error of Mean: 48.56%
#
# Frame 3469 (Hour 3469) All Locations - Raw RMSE: 2.23
# Frame 3469 (Hour 3469) All Locations - RMSE Percent Error of Mean: 19.09%
#
# Frame 3470 (Hour 3470) All Locations - Raw RMSE: 3.86
# Frame 3470 (Hour 3470) All Locations - RMSE Percent Error of Mean: 37.07%
#
# Frame 3471 (Hour 3471) All Locations - Raw RMSE: 2.52
# Frame 3471 (Hour 3471) All Locations - RMSE Percent Error of Mean: 29.30%
#
# Frame 3472 (Hour 3472) All Locations - Raw RMSE: 2.93
# Frame 3472 (Hour 3472) All Locations - RMSE Percent Error of Mean: 38.79%
#
# Frame 3473 (Hour 3473) All Locations - Raw RMSE: 1.34
# Frame 3473 (Hour 3473) All Locations - RMSE Percent Error of Mean: 20.19%
#
# Frame 3474 (Hour 3474) All Locations - Raw RMSE: 1.10
# Frame 3474 (Hour 3474) All Locations - RMSE Percent Error of Mean: 17.81%
#
# Frame 3475 (Hour 3475) All Locations - Raw RMSE: 1.02
# Frame 3475 (Hour 3475) All Locations - RMSE Percent Error of Mean: 18.37%
#
# Frame 3476 (Hour 3476) All Locations - Raw RMSE: 1.15
# Frame 3476 (Hour 3476) All Locations - RMSE Percent Error of Mean: 20.47%
#
# Frame 3477 (Hour 3477) All Locations - Raw RMSE: 1.08
# Frame 3477 (Hour 3477) All Locations - RMSE Percent Error of Mean: 20.37%
#
# Frame 3478 (Hour 3478) All Locations - Raw RMSE: 0.90
# Frame 3478 (Hour 3478) All Locations - RMSE Percent Error of Mean: 17.36%
#
# Frame 3479 (Hour 3479) All Locations - Raw RMSE: 1.42
# Frame 3479 (Hour 3479) All Locations - RMSE Percent Error of Mean: 32.41%
#
# Frame 3480 (Hour 3480) All Locations - Raw RMSE: 0.92
# Frame 3480 (Hour 3480) All Locations - RMSE Percent Error of Mean: 27.08%
#
# Frame 3481 (Hour 3481) All Locations - Raw RMSE: 1.28
# Frame 3481 (Hour 3481) All Locations - RMSE Percent Error of Mean: 44.51%
#
# Frame 3482 (Hour 3482) All Locations - Raw RMSE: 1.03
# Frame 3482 (Hour 3482) All Locations - RMSE Percent Error of Mean: 38.60%
#
# Frame 3483 (Hour 3483) All Locations - Raw RMSE: 1.12
# Frame 3483 (Hour 3483) All Locations - RMSE Percent Error of Mean: 37.65%
#
# Frame 3484 (Hour 3484) All Locations - Raw RMSE: 2.77
# Frame 3484 (Hour 3484) All Locations - RMSE Percent Error of Mean: 61.45%
#
# Frame 3485 (Hour 3485) All Locations - Raw RMSE: 2.04
# Frame 3485 (Hour 3485) All Locations - RMSE Percent Error of Mean: 38.52%
#
# Frame 3486 (Hour 3486) All Locations - Raw RMSE: 1.55
# Frame 3486 (Hour 3486) All Locations - RMSE Percent Error of Mean: 25.18%
#
# Frame 3487 (Hour 3487) All Locations - Raw RMSE: 3.01
# Frame 3487 (Hour 3487) All Locations - RMSE Percent Error of Mean: 34.31%
#
# Frame 3488 (Hour 3488) All Locations - Raw RMSE: 1.70
# Frame 3488 (Hour 3488) All Locations - RMSE Percent Error of Mean: 17.09%
#
# Frame 3489 (Hour 3489) All Locations - Raw RMSE: 3.05
# Frame 3489 (Hour 3489) All Locations - RMSE Percent Error of Mean: 29.76%
#
# Frame 3490 (Hour 3490) All Locations - Raw RMSE: 3.45
# Frame 3490 (Hour 3490) All Locations - RMSE Percent Error of Mean: 33.36%
#
# Frame 3491 (Hour 3491) All Locations - Raw RMSE: 2.90
# Frame 3491 (Hour 3491) All Locations - RMSE Percent Error of Mean: 32.34%
#
# Frame 3492 (Hour 3492) All Locations - Raw RMSE: 3.42
# Frame 3492 (Hour 3492) All Locations - RMSE Percent Error of Mean: 41.29%
#
# Frame 3493 (Hour 3493) All Locations - Raw RMSE: 3.39
# Frame 3493 (Hour 3493) All Locations - RMSE Percent Error of Mean: 43.00%
#
# Frame 3494 (Hour 3494) All Locations - Raw RMSE: 3.34
# Frame 3494 (Hour 3494) All Locations - RMSE Percent Error of Mean: 47.60%
#
# Frame 3495 (Hour 3495) All Locations - Raw RMSE: 2.82
# Frame 3495 (Hour 3495) All Locations - RMSE Percent Error of Mean: 47.30%
#
# Frame 3496 (Hour 3496) All Locations - Raw RMSE: 2.55
# Frame 3496 (Hour 3496) All Locations - RMSE Percent Error of Mean: 45.95%
#
# Frame 3497 (Hour 3497) All Locations - Raw RMSE: 2.49
# Frame 3497 (Hour 3497) All Locations - RMSE Percent Error of Mean: 47.16%
#
# Frame 3498 (Hour 3498) All Locations - Raw RMSE: 2.21
# Frame 3498 (Hour 3498) All Locations - RMSE Percent Error of Mean: 47.33%
#
# Frame 3499 (Hour 3499) All Locations - Raw RMSE: 1.90
# Frame 3499 (Hour 3499) All Locations - RMSE Percent Error of Mean: 38.40%
#
# Frame 3500 (Hour 3500) All Locations - Raw RMSE: 2.42
# Frame 3500 (Hour 3500) All Locations - RMSE Percent Error of Mean: 46.38%
#
# Frame 3501 (Hour 3501) All Locations - Raw RMSE: 2.28
# Frame 3501 (Hour 3501) All Locations - RMSE Percent Error of Mean: 52.91%
#
# Frame 3502 (Hour 3502) All Locations - Raw RMSE: 1.44
# Frame 3502 (Hour 3502) All Locations - RMSE Percent Error of Mean: 50.62%
#
# Frame 3503 (Hour 3503) All Locations - Raw RMSE: 1.56
# Frame 3503 (Hour 3503) All Locations - RMSE Percent Error of Mean: 83.15%
#
# Frame 3504 (Hour 3504) All Locations - Raw RMSE: 1.40
# Frame 3504 (Hour 3504) All Locations - RMSE Percent Error of Mean: 65.60%
#
# Frame 3505 (Hour 3505) All Locations - Raw RMSE: 1.03
# Frame 3505 (Hour 3505) All Locations - RMSE Percent Error of Mean: 45.97%
#
# Frame 3506 (Hour 3506) All Locations - Raw RMSE: 2.07
# Frame 3506 (Hour 3506) All Locations - RMSE Percent Error of Mean: 83.20%
#
# Frame 3507 (Hour 3507) All Locations - Raw RMSE: 1.36
# Frame 3507 (Hour 3507) All Locations - RMSE Percent Error of Mean: 42.76%
#
# Frame 3508 (Hour 3508) All Locations - Raw RMSE: 1.53
# Frame 3508 (Hour 3508) All Locations - RMSE Percent Error of Mean: 47.85%
#
# RESULTS BY SENSOR LOCATION
# ---------------------------------------------------------------------------
# All Days - Simi Valley - Cochran Street Raw RMSE: 1.89
# All Days - Simi Valley - Cochran Street RMSE Percent Error of Mean: 25.73%
#
# All Days - Reseda Raw RMSE: 2.25
# All Days - Reseda RMSE Percent Error of Mean: 23.47%
#
# All Days - Santa Clarita Raw RMSE: 2.09
# All Days - Santa Clarita RMSE Percent Error of Mean: 18.31%
#
# All Days - North Holywood Raw RMSE: 2.52
# All Days - North Holywood RMSE Percent Error of Mean: 20.54%
#
# All Days - Los Angeles - N. Main Street Raw RMSE: 2.72
# All Days - Los Angeles - N. Main Street RMSE Percent Error of Mean: 19.59%
#
# All Days - Compton Raw RMSE: 5.44
# All Days - Compton RMSE Percent Error of Mean: 53.98%
#
# All Days - Long Beach Signal Hill Raw RMSE: 4.29
# All Days - Long Beach Signal Hill RMSE Percent Error of Mean: 48.12%
#
# All Days - Glendora - Laurel Raw RMSE: 3.51
# All Days - Glendora - Laurel RMSE Percent Error of Mean: 32.55%
