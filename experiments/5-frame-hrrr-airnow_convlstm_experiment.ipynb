# %% [markdown]
# # Test 2: 5-frame-forecast-HRRR + AirNow predicting stations

# %% [markdown]
# ## HRRR preprocessing

# %%
# define bounding box
lat_bottom, lat_top = 33.9, 34.2
lon_bottom, lon_top = -118.4, -118.0
extent = (lon_bottom, lon_top, lat_bottom, lat_top)

# input data shape
dim = 200
frames_per_sample = 5

# date range of data
start_date, end_date = "2025-01-10-00", "2025-01-17-00"

# %%
# python nonsense that allows you to import from sibling directories
import sys
sys.path.append("..")

# %%
from libs.hrrrdata import HRRRData
HD = HRRRData(
    start_date=start_date,
    end_date=end_date,
    extent=extent,
    extent_name='la_region2',
    product='MASSDEN',
    frames_per_sample=frames_per_sample,
    sample_setting=2, # uses n-frame-forecast sampling
    dim=dim,
    verbose=True
)
# Out:
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 04:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 04:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 04:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 04:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 04:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 05:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 05:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 05:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 05:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 05:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 06:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 06:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 06:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 06:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 06:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 07:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 07:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 07:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 07:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 07:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 08:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 08:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 08:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 08:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 08:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 09:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 09:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 09:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 09:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 09:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 10:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 10:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 10:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 10:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 10:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 11:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 11:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 11:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 11:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 11:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 12:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 12:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 12:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 12:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 12:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 13:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 13:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 13:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 13:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 13:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 14:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 14:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 14:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 14:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 14:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 15:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 15:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 15:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 15:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 15:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 16:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 16:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 16:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 16:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 16:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 17:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 17:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 17:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 17:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 17:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 18:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 18:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 18:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 18:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 18:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 19:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 19:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 19:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 19:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 19:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 20:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 20:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 20:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 20:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 20:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 21:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 21:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 21:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 21:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 21:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 22:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 22:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 22:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 22:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 22:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 23:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 23:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 23:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 23:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-10 23:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 00:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 00:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 00:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 00:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 00:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 01:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 01:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 01:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 01:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 01:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 02:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 02:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 02:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 02:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 02:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 03:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 03:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 03:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 03:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 03:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 04:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 04:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 04:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 04:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 04:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 06:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 06:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 06:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 06:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 06:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 07:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 07:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 07:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 07:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 07:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 08:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 08:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 08:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 08:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 08:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 09:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 09:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 09:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 09:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 09:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 10:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 10:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 10:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 10:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 10:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 11:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 11:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 11:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 11:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 11:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 12:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 12:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 12:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 12:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 12:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 13:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 13:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 13:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 13:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 13:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 14:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 14:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 14:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 14:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 14:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 15:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 15:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 15:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 15:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 15:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 16:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 16:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 16:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 16:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 16:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 17:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 17:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 17:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 17:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 17:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 18:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 18:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 18:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 18:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 18:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 19:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 19:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 19:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 19:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 19:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 20:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 20:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 20:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 20:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 20:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 21:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 21:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 21:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 21:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 21:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 22:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 22:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 22:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 22:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 22:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 23:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 23:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 23:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 23:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 23:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 00:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 00:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 00:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 00:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 00:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 01:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 01:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 01:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 01:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 01:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 02:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 02:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 02:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 02:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 02:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 03:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 03:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 03:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 03:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 03:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 04:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 04:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 04:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 04:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 04:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 05:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 05:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 05:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 05:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 05:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 06:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 06:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 06:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 06:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 06:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 07:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 07:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 07:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 07:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 07:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 08:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 08:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 08:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 08:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 08:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 09:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 09:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 09:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 09:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 09:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 10:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 10:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 10:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 10:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 10:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 11:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 11:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 11:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 11:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 11:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 12:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 12:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 12:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 12:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 12:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 13:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 13:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 13:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 13:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 13:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 14:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 14:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 14:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 14:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 14:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 15:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 15:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 15:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 15:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 15:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 16:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 16:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 16:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 16:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 16:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 17:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 17:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 17:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 17:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 17:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 18:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 18:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 18:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 18:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 18:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 19:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 19:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 19:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 19:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 19:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 20:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 20:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 20:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 20:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 20:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 21:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 21:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 21:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 21:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 21:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 22:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 22:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 22:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 22:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 22:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 23:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 23:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 23:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 23:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-12 23:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 00:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 00:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 00:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 00:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 00:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 01:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 01:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 01:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 01:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 01:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 02:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 02:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 02:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 02:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 02:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 03:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 03:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 03:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 03:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 03:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 04:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 04:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 04:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 04:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 04:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 05:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 05:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 05:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 05:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 05:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 06:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 06:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 06:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 06:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 06:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 07:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 07:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 07:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 07:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 07:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 08:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 08:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 08:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 08:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 08:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 09:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 09:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 09:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 09:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 09:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 10:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 10:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 10:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 10:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 10:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 11:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 11:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 11:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 11:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 11:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 12:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 12:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 12:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 12:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 12:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 13:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 13:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 13:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 13:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 13:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 14:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 14:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 14:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 14:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 14:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 15:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 15:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 15:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 15:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 15:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 16:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 16:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 16:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 16:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 16:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 17:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 17:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 17:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 17:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 17:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 18:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 18:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 18:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 18:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 18:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 19:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 19:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 19:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 19:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 19:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 20:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 20:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 20:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 20:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 20:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 21:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 21:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 21:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 21:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 21:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 22:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 22:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 22:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 22:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 22:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 23:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 23:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 23:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 23:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-13 23:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 00:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 00:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 00:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 00:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 00:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 01:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 01:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 01:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 01:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 01:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 02:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 02:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 02:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 02:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 02:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 03:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 03:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 03:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 03:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 03:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 04:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 04:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 04:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 04:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 04:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 05:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 05:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 05:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 05:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 05:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 06:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 06:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 06:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 06:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 06:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 07:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 07:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 07:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 07:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 07:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 08:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 08:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 08:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 08:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 08:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 09:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 09:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 09:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 09:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 09:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 10:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 10:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 10:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 10:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 10:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 11:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 11:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 11:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 11:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 11:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 12:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 12:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 12:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 12:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 12:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 13:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 13:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 13:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 13:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 13:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 14:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 14:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 14:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 14:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 14:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 15:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 15:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 15:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 15:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 15:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 16:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 16:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 16:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 16:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 16:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 17:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 17:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 17:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 17:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 17:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 18:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 18:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 18:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 18:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 18:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 19:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 19:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 19:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 19:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 19:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 20:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 20:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 20:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 20:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 20:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 21:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 21:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 21:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 21:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 21:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 22:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 22:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 22:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 22:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 22:00 UTC F05 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 23:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 23:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-14 23:00 UTC F03 ┊ source=aws
# ...
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_fae49dd4__hrrr.t02z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_fa219dd4__hrrr.t02z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_fa159dd4__hrrr.t02z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_fa4b9dd4__hrrr.t02z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_fa1a9dd4__hrrr.t02z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_0ee49dd4__hrrr.t03z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_0e219dd4__hrrr.t03z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_0e159dd4__hrrr.t03z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_0e4b9dd4__hrrr.t03z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_0e1a9dd4__hrrr.t03z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_bde49dd4__hrrr.t04z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_bd219dd4__hrrr.t04z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_bd159dd4__hrrr.t04z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_bd4b9dd4__hrrr.t04z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_bd1a9dd4__hrrr.t04z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_a8e49dd4__hrrr.t05z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_a8219dd4__hrrr.t05z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_a8159dd4__hrrr.t05z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_a84b9dd4__hrrr.t05z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_a81a9dd4__hrrr.t05z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_37e49dd4__hrrr.t06z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_37219dd4__hrrr.t06z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_37159dd4__hrrr.t06z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_374b9dd4__hrrr.t06z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_371a9dd4__hrrr.t06z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_e7e49dd4__hrrr.t07z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_e7219dd4__hrrr.t07z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_e7159dd4__hrrr.t07z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_e74b9dd4__hrrr.t07z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_e71a9dd4__hrrr.t07z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_4be49dd4__hrrr.t08z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_4b219dd4__hrrr.t08z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_4b159dd4__hrrr.t08z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_4b4b9dd4__hrrr.t08z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_4b1a9dd4__hrrr.t08z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_c7e49dd4__hrrr.t09z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_c7219dd4__hrrr.t09z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_c7159dd4__hrrr.t09z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_c74b9dd4__hrrr.t09z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_c71a9dd4__hrrr.t09z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_35e49dd4__hrrr.t10z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_35219dd4__hrrr.t10z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_35159dd4__hrrr.t10z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_354b9dd4__hrrr.t10z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_351a9dd4__hrrr.t10z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_18e49dd4__hrrr.t11z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_18219dd4__hrrr.t11z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_18159dd4__hrrr.t11z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_184b9dd4__hrrr.t11z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_181a9dd4__hrrr.t11z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_b5e49dd4__hrrr.t12z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_b5219dd4__hrrr.t12z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_b5159dd4__hrrr.t12z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_b54b9dd4__hrrr.t12z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_b51a9dd4__hrrr.t12z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_dae49dd4__hrrr.t13z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_da219dd4__hrrr.t13z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_da159dd4__hrrr.t13z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_da4b9dd4__hrrr.t13z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_da1a9dd4__hrrr.t13z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_8ee49dd4__hrrr.t14z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_8e219dd4__hrrr.t14z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_8e159dd4__hrrr.t14z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_8e4b9dd4__hrrr.t14z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_8e1a9dd4__hrrr.t14z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_91e49dd4__hrrr.t15z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_91219dd4__hrrr.t15z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_91159dd4__hrrr.t15z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_914b9dd4__hrrr.t15z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_911a9dd4__hrrr.t15z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_2fe49dd4__hrrr.t16z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_2f219dd4__hrrr.t16z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_2f159dd4__hrrr.t16z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_2f4b9dd4__hrrr.t16z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_2f1a9dd4__hrrr.t16z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_efe49dd4__hrrr.t17z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_ef219dd4__hrrr.t17z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_ef159dd4__hrrr.t17z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_ef4b9dd4__hrrr.t17z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_ef1a9dd4__hrrr.t17z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_46e49dd4__hrrr.t18z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_46219dd4__hrrr.t18z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_46159dd4__hrrr.t18z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_464b9dd4__hrrr.t18z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_461a9dd4__hrrr.t18z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_5be49dd4__hrrr.t19z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_5b219dd4__hrrr.t19z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_5b159dd4__hrrr.t19z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_5b4b9dd4__hrrr.t19z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_5b1a9dd4__hrrr.t19z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_aae49dd4__hrrr.t20z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_aa219dd4__hrrr.t20z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_aa159dd4__hrrr.t20z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_aa4b9dd4__hrrr.t20z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_aa1a9dd4__hrrr.t20z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_3be49dd4__hrrr.t21z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_3b219dd4__hrrr.t21z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_3b159dd4__hrrr.t21z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_3b4b9dd4__hrrr.t21z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_3b1a9dd4__hrrr.t21z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_90e49dd4__hrrr.t22z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_90219dd4__hrrr.t22z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_90159dd4__hrrr.t22z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_904b9dd4__hrrr.t22z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_901a9dd4__hrrr.t22z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_70e49dd4__hrrr.t23z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_70219dd4__hrrr.t23z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_70159dd4__hrrr.t23z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_704b9dd4__hrrr.t23z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250116/la_region2_subset_701a9dd4__hrrr.t23z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250117/la_region2_subset_dee49dd4__hrrr.t00z.wrfsfcf01.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250117/la_region2_subset_de219dd4__hrrr.t00z.wrfsfcf02.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250117/la_region2_subset_de159dd4__hrrr.t00z.wrfsfcf03.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250117/la_region2_subset_de4b9dd4__hrrr.t00z.wrfsfcf04.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/home/mgraca/data/hrrr/20250117/la_region2_subset_de1a9dd4__hrrr.t00z.wrfsfcf05.grib2.5b7b6.idx' older than GRIB file

# %%
X_hrrr = HD.data
print(X_hrrr.shape)
# Out:
# (165, 5, 200, 200, 1)

# %%
# convert kg to micrograms (may offload into library)
ug_per_kg = 1000000000
X_hrrr = X_hrrr * ug_per_kg

# %%
import matplotlib.pyplot as plt
import numpy as np

# Construct a figure on which we will visualize the images.
fig, axes = plt.subplots(1, 5, figsize=(10, 4))

# Plot each of the sequential images for one random data example.
# plot hrrr channel
np.random.seed(150)
rand_sample = np.random.choice(range(len(X_hrrr)))
for idx, ax in enumerate(axes):
    ax.imshow(np.squeeze(X_hrrr[rand_sample, idx, :, :, 0]))
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

# Print information and display the figure.
print(f"Displaying frames for example {rand_sample}.")
print("Products used:")
for H in HD.herbie[rand_sample*frames_per_sample:rand_sample*frames_per_sample+frames_per_sample]:
    print(repr(H))

plt.show()
# Out:
# Displaying frames for example 25.
# Products used:
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F01 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F02 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F03 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F04 ┊ source=aws
# ▌▌Herbie HRRR model sfc product initialized 2025-Jan-11 05:00 UTC F05 ┊ source=aws

# %% [markdown]
# ## AirNow preprocessing

# %%
# use library to get AirNow data...
'''
from libs.airnowdata import AirNowData
AD = AirNowData(
    start_date=start_date,
    end_date=end_date,
    extent=extent,
    airnow_api_key=None,
    save_dir='../data/airnow.json',
    frames_per_sample=frames_per_sample,
    dim=dim,
    elevation_path="../data/interpolation/elevation.npy",
    mask_path="../data/interpolation/no_mask.npy"
)

X_airnow = AD.data
Y = AD.target_stations
'''

# ...or use precomputed AirNow data
import numpy as np

def precomputed_airnow(
    X_path="/home/mgraca/data/precomputed/airnow_features_experiment_1.npy",
    y_path="/home/mgraca/data/precomputed/airnow_target_experiment_1.npy"
):
    X, y = np.load(X_path), np.load(y_path)
    return X, y

# %%
X_airnow, Y = precomputed_airnow()
print(X_airnow.shape)
print(Y.shape)
# Out:
# (165, 5, 200, 200, 1)
# (165, 3)

# %% [markdown]
# ## Joint preprocessing
# - Split into train/test sets
# - Scale train/test sets independently
# - Combine X datasets into 1 with 2 channels

# %%
# split data
def train_test_split(X, train_size=0.75):
    split_idx = int(X.shape[0] * train_size)
    X_train, X_test = X[:split_idx], X[split_idx:]
    
    return X_train, X_test

# scale training data, then scale test data based on training data stats
from sklearn.preprocessing import StandardScaler
def std_scale(X_train, X_test):
    scaler = StandardScaler()
    scaled_train = scaler.fit_transform(X_train.reshape(-1, 1)).reshape(X_train.shape)
    scaled_test = scaler.transform(X_test.reshape(-1, 1)).reshape(X_test.shape)

    return scaled_train, scaled_test

# %%
import numpy as np

# split data
X_hrrr_train, X_hrrr_test = train_test_split(X_hrrr, train_size=0.75)
X_airnow_train, X_airnow_test = train_test_split(X_airnow, train_size=0.75)
y_train, y_test = train_test_split(Y, train_size=0.75)

# scale training data, then test data based on training data's stats
X_hrrr_train, X_hrrr_test = std_scale(X_hrrr_train, X_hrrr_test)
X_airnow_train, X_airnow_test = std_scale(X_airnow_train, X_airnow_test)

# combine each data source into one tensor, by channel
X_train = np.concatenate([X_hrrr_train, X_airnow_train], axis=-1)
X_test = np.concatenate([X_hrrr_test, X_airnow_test], axis=-1)

print("HRRR and AirNow, combined by channel:")
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# HRRR and AirNow, combined by channel:
# (123, 5, 200, 200, 2) (42, 5, 200, 200, 2)
# (123, 3) (42, 3)

# %% [markdown]
# ## Final input viz

# %%
import matplotlib.pyplot as plt

# Construct a figure on which we will visualize the images.
fig, axes = plt.subplots(2, 5, figsize=(10, 4))

# Plot each of the sequential images for one random data example.
# plot hrrr channel
np.random.seed(42)
rand_sample = np.random.choice(range(len(X_train)))
for idx, ax in enumerate(axes[0]):
    ax.imshow(np.squeeze(X_train[rand_sample, idx, :, :, 0]))
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")
# plot airnow channel
for idx, ax in enumerate(axes[1]):
    ax.imshow(np.squeeze(X_train[rand_sample, idx, :, :, 1]))
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

# Print information and display the figure.
print(f"Displaying frames for example {rand_sample}.")
plt.show()

print("Target: ", y_train[rand_sample])
# Out:
# Displaying frames for example 102.
# Target:  [11.1 11.2 19.7]

# %% [markdown]
# ## Model

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv3D
from keras.layers import ConvLSTM2D
from keras.layers import BatchNormalization
from keras.layers import Convolution2D, MaxPooling3D, Flatten, Reshape
from keras.layers import TimeDistributed
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import InputLayer
# Out:
# 2025-04-22 14:37:14.554500: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-22 14:37:14.562497: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745357834.572888   91512 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745357834.576257   91512 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 14:37:14.586410: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.keras.backend.set_image_data_format('channels_last')

seq = Sequential()

seq.add(
    InputLayer(shape=(5, 200, 200, 2))
)

seq.add(
    ConvLSTM2D(
            filters=15, 
            kernel_size=(3, 3),
            padding='same', 
            return_sequences=True
    )
)

seq.add(
    ConvLSTM2D(
        filters=30, 
        kernel_size=(3, 3),
        padding='same', 
        return_sequences=True
    )
)

seq.add(
    Conv3D(
        filters=15, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'    
    )
)

seq.add(
    Conv3D(
        filters=1, 
        kernel_size=(3, 3, 3),
        activation='relu',
        padding='same'
    )
)

seq.add(Flatten())

seq.add(Dense(3,activation='relu'))

seq.compile(loss='mean_absolute_error', optimizer='adam')
seq.summary()
# Out:
# I0000 00:00:1745357835.763298   91512 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 5, 200, 200,    │         9,240 │
# │                                 │ 15)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 5, 200, 200,    │        48,720 │
# │                                 │ 30)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 5, 200, 200,    │        12,165 │
# │                                 │ 15)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 5, 200, 200, 1) │           406 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200000)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │       600,003 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 670,534 (2.56 MB)
#  Trainable params: 670,534 (2.56 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train and test

# %%
seq.fit(X_train, y_train, batch_size=4, epochs=150)
# Out:
# Epoch 1/150
# I0000 00:00:1745357838.340476  105917 service.cc:148] XLA service 0x75fec4017f80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745357838.340505  105917 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2025-04-22 14:37:18.422780: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1745357838.694156  105917 cuda_dnn.cc:529] Loaded cuDNN version 90800
# E0000 00:00:1745357839.274360  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357839.451288  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357839.800602  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357839.979762  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-22 14:37:20.246702: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[4,30,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,15,200,200]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[4,30,200,200]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# E0000 00:00:1745357840.613773  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357840.789005  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-22 14:37:20.957639: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[4,15,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,2,200,200]{3,2,1,0}, f32[15,2,3,3]{3,2,1,0}, f32[15]{0}, f32[4,15,200,200]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# I0000 00:00:1745357844.472380  105917 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 13.6246
# E0000 00:00:1745357849.877749  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357850.055576  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357850.389151  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357850.564722  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357851.122869  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745357851.297275  105917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 18s 337ms/step - loss: 13.5106
# Epoch 2/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 8.1571
# Epoch 3/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 9.3408
# Epoch 4/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 7.5972
# Epoch 5/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 7.2216
# Epoch 6/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 8.1167
# Epoch 7/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 7.0919
# Epoch 8/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 8.4739
# Epoch 9/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 6.6796
# Epoch 10/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 7.4837
# Epoch 11/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 6.4982
# Epoch 12/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 6.6746
# Epoch 13/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 5.9449
# Epoch 14/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 5.2777
# Epoch 15/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 5.0229
# Epoch 16/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 4.9881
# Epoch 17/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 5.3854
# Epoch 18/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 4.9632
# Epoch 19/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 4.4554
# Epoch 20/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 4.4476
# Epoch 21/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 4.1116
# Epoch 22/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 3.7273
# Epoch 23/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 4.3041
# Epoch 24/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 3.1061
# Epoch 25/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 3.7674
# Epoch 26/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 3.3163
# Epoch 27/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 3.6183
# Epoch 28/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 4.8594
# Epoch 29/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 3.1746
# Epoch 30/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.4502
# Epoch 31/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.9912
# Epoch 32/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.6901
# Epoch 33/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.8104
# Epoch 34/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 3.5395
# Epoch 35/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 2.9893
# Epoch 36/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 2.7535
# Epoch 37/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.4424
# Epoch 38/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 2.5061
# Epoch 39/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 2.8086
# Epoch 40/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 3.1686
# Epoch 41/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 2.6421
# Epoch 42/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 3.0318
# Epoch 43/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.2976
# Epoch 44/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.5057
# Epoch 45/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 2.8197
# Epoch 46/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.5161
# Epoch 47/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.6762
# Epoch 48/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.2535
# Epoch 49/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.4611
# Epoch 50/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.2901
# Epoch 51/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1141
# Epoch 52/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.4140
# Epoch 53/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.8521
# Epoch 54/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.6408
# Epoch 55/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.8185
# Epoch 56/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.5711
# Epoch 57/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.3945
# Epoch 58/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.4568
# Epoch 59/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.8854
# Epoch 60/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 3.0743
# Epoch 61/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 3.1270
# Epoch 62/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.7882
# Epoch 63/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.4071
# Epoch 64/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.9957
# Epoch 65/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.6099
# Epoch 66/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.4051
# Epoch 67/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.1381
# Epoch 68/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.2646
# Epoch 69/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.9139
# Epoch 70/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.0748
# Epoch 71/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.2878
# Epoch 72/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.2299
# Epoch 73/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.5775
# Epoch 74/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.9661
# Epoch 75/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.4150
# Epoch 76/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.8722
# Epoch 77/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 1.9597
# Epoch 78/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1763
# Epoch 79/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1934
# Epoch 80/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.0065
# Epoch 81/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 3.1417
# Epoch 82/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.9442
# Epoch 83/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.3027
# Epoch 84/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.3636
# Epoch 85/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.6371
# Epoch 86/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.6482
# Epoch 87/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.7663
# Epoch 88/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 3.0537
# Epoch 89/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.3492
# Epoch 90/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.4567
# Epoch 91/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.2811
# Epoch 92/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.2903
# Epoch 93/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.3462
# Epoch 94/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.1685
# Epoch 95/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.3190
# Epoch 96/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.3601
# Epoch 97/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 3.3382
# Epoch 98/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 2.8947
# Epoch 99/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 1.9262
# Epoch 100/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 2.1582
# Epoch 101/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.2205
# Epoch 102/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 2.3061
# Epoch 103/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.6326
# Epoch 104/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.0290
# Epoch 105/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.6035
# Epoch 106/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.6825
# Epoch 107/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.0875
# Epoch 108/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 2.0116
# Epoch 109/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.9314
# Epoch 110/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 2.0515
# Epoch 111/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 2.3746
# Epoch 112/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 1.8881
# Epoch 113/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.0816
# Epoch 114/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.1185
# Epoch 115/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 2.5599
# Epoch 116/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 1.9899
# Epoch 117/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.3345
# Epoch 118/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.4912
# Epoch 119/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.2283
# Epoch 120/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 2.0917
# Epoch 121/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.2399
# Epoch 122/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.2870
# Epoch 123/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.1488
# Epoch 124/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.3111
# Epoch 125/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.2907
# Epoch 126/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.4459
# Epoch 127/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.3517
# Epoch 128/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.0167
# Epoch 129/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1534
# Epoch 130/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.9994
# Epoch 131/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.3674
# Epoch 132/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.5287
# Epoch 133/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 2.3755
# Epoch 134/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.8530
# Epoch 135/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.7429
# Epoch 136/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1921
# Epoch 137/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1323
# Epoch 138/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.3915
# Epoch 139/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1589
# Epoch 140/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.0185
# Epoch 141/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 1.6449
# Epoch 142/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 1.8272
# Epoch 143/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 2.1946
# Epoch 144/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.9396
# Epoch 145/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.8864
# Epoch 146/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.9175
# Epoch 147/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 1.7311
# Epoch 148/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.1122
# Epoch 149/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 2.0228
# Epoch 150/150
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 1.7909

# %%
y_pred = seq.predict(X_test, verbose=0)
print(y_test.shape, y_pred.shape)
# Out:
# 2025-04-22 14:49:28.602415: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,15,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,2,200,200]{3,2,1,0}, f32[15,2,3,3]{3,2,1,0}, f32[15]{0}, f32[32,15,200,200]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-22 14:49:29.043827: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[32,30,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,15,200,200]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[32,30,200,200]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-22 14:49:32.001736: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,15,5,200,200]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[32,30,5,200,200]{4,3,2,1,0}, f32[15,30,3,3,3]{4,3,2,1,0}, f32[15]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-04-22 14:49:32.080752: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.079113984s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,15,5,200,200]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[32,30,5,200,200]{4,3,2,1,0}, f32[15,30,3,3,3]{4,3,2,1,0}, f32[15]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-04-22 14:49:34.046329: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[10,15,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[10,2,200,200]{3,2,1,0}, f32[15,2,3,3]{3,2,1,0}, f32[15]{0}, f32[10,15,200,200]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-22 14:49:34.236025: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[10,30,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[10,15,200,200]{3,2,1,0}, f32[30,15,3,3]{3,2,1,0}, f32[30]{0}, f32[10,30,200,200]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":1},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# (42, 3) (42, 3)

# %%
from skimage.metrics import mean_squared_error as mse

# hardcode for now
air_sensor_loc = ["North Holywood", "Los Angeles - N. Main Street", "Compton"]

def rmse(y_pred, y_test):
    return np.sqrt(mse(y_pred, y_test))

def nrmse(y_pred, y_test):
    return rmse(y_pred, y_test) / np.mean(y_test) * 100
    
print("Input: Interpolated Previous PM2.5 Sensor data + HRRR-smoke data")
print("Output: Future PM 2.5 Sensor data at 6 Locations in LA County Hourly (Using 5 previous frames to predict 5 future frames) \n")

print("RESULTS")
print("---------------------------------------------------------------------------")
print(f"All Days All Locations - y_pred vs y_test Raw RMSE: {rmse(y_pred, y_test):.2f}")
print(f"All Days All Locations - y_pred vs y_test RMSE Percent Error of Mean: {nrmse(y_pred, y_test):.2f}%\n")

print("RESULTS BY FRAME")
print("---------------------------------------------------------------------------")
for i in range(5):
    print(f"Frame {i+1} (Hour {i+1}) All Locations - Raw RMSE: {rmse(y_pred[i,:], y_test[i,:]):.2f}")
    print(f"Frame {i+1} (Hour {i+1}) All Locations - RMSE Percent Error of Mean: {nrmse(y_pred[i,:], y_test[i,:]):.2f}%\n")

print("RESULTS BY SENSOR LOCATION")
print("---------------------------------------------------------------------------")
#for i, loc in enumerate(list(AD.air_sens_loc.keys())):
for i, loc in enumerate(air_sensor_loc):
    print(f"All Days - {loc} Raw RMSE: {rmse(y_pred[:,i], y_test[:,i]):.2f}")
    print(f"All Days - {loc} RMSE Percent Error of Mean: {nrmse(y_pred[:,i], y_test[:,i]):.2f}%\n")
# Out:
# Input: Interpolated Previous PM2.5 Sensor data + HRRR-smoke data
# Output: Future PM 2.5 Sensor data at 6 Locations in LA County Hourly (Using 5 previous frames to predict 5 future frames)
#
# RESULTS
# ---------------------------------------------------------------------------
# All Days All Locations - y_pred vs y_test Raw RMSE: 2.96
# All Days All Locations - y_pred vs y_test RMSE Percent Error of Mean: 26.87%
#
# RESULTS BY FRAME
# ---------------------------------------------------------------------------
# Frame 1 (Hour 1) All Locations - Raw RMSE: 2.32
# Frame 1 (Hour 1) All Locations - RMSE Percent Error of Mean: 15.09%
#
# Frame 2 (Hour 2) All Locations - Raw RMSE: 1.43
# Frame 2 (Hour 2) All Locations - RMSE Percent Error of Mean: 10.36%
#
# Frame 3 (Hour 3) All Locations - Raw RMSE: 2.53
# Frame 3 (Hour 3) All Locations - RMSE Percent Error of Mean: 18.41%
#
# Frame 4 (Hour 4) All Locations - Raw RMSE: 0.64
# Frame 4 (Hour 4) All Locations - RMSE Percent Error of Mean: 4.53%
#
# Frame 5 (Hour 5) All Locations - Raw RMSE: 1.00
# Frame 5 (Hour 5) All Locations - RMSE Percent Error of Mean: 7.25%
#
# RESULTS BY SENSOR LOCATION
# ---------------------------------------------------------------------------
# All Days - North Holywood Raw RMSE: 3.22
# All Days - North Holywood RMSE Percent Error of Mean: 30.78%
#
# All Days - Los Angeles - N. Main Street Raw RMSE: 2.66
# All Days - Los Angeles - N. Main Street RMSE Percent Error of Mean: 27.65%
#
# All Days - Compton Raw RMSE: 2.98
# All Days - Compton RMSE Percent Error of Mean: 22.94%

# %% [markdown]
# ## RMSE results visualization

# %%
print("\nVisualizing model predictions vs actual values...")

# Choose the first test sample for consistent visualizations
sample_idx = 0

# Create a bar chart comparing predicted vs actual values for each sensor
fig, ax = plt.subplots(figsize=(12, 6))
#sensor_names = list(AD.air_sens_loc.keys())
sensor_names = air_sensor_loc
x = np.arange(len(sensor_names))
width = 0.35

true_vals = y_test[sample_idx]
pred_vals = y_pred[sample_idx]

rects1 = ax.bar(x - width/2, true_vals, width, label='Actual')
rects2 = ax.bar(x + width/2, pred_vals, width, label='Predicted')

ax.set_title('PM2.5 Actual vs. Predicted Values by Sensor Location')
ax.set_ylabel('PM2.5 Value')
ax.set_xlabel('Sensor Location')
ax.set_xticks(x)
ax.set_xticklabels(sensor_names, rotation=45, ha='right')
ax.legend()

#plt.tight_layout()
plt.show()

# Visualize input data for a specific sample
fig, axes = plt.subplots(2, 5, figsize=(15, 6))

# Plot hrrr data (channel 0)
for idx, ax in enumerate(axes[0]):
    im = ax.imshow(np.squeeze(X_test[sample_idx, idx, :, :, 0]), cmap='viridis')
    ax.set_title(f"HRRR Frame {idx + 1}")
    ax.axis("off")

# Plot AirNow data (channel 1)
for idx, ax in enumerate(axes[1]):
    im = ax.imshow(np.squeeze(X_test[sample_idx, idx, :, :, 1]), cmap='viridis')
    ax.set_title(f"AirNow Frame {idx + 1}")
    ax.axis("off")

plt.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
plt.suptitle(f'Input data for sample {sample_idx}')
#plt.tight_layout()
plt.show()

# Create a scatter plot of predicted vs actual values
plt.figure(figsize=(10, 8))
plt.scatter(y_test.flatten(), y_pred.flatten(), alpha=0.5)
plt.plot([0, np.max(y_test)], [0, np.max(y_test)], 'r--')  # Perfect prediction line
plt.xlabel('Actual PM2.5 Values')
plt.ylabel('Predicted PM2.5 Values')
plt.title('Actual vs. Predicted PM2.5 Values')
plt.grid(True)
#plt.tight_layout()
plt.show()

# Compute error metrics for each sensor
error_by_sensor = []
for i, sensor in enumerate(sensor_names):
    error = rmse(y_pred[:, i], y_test[:, i])
    error_by_sensor.append(error)

# Create bar chart of errors by sensor
plt.figure(figsize=(10, 6))
plt.bar(sensor_names, error_by_sensor)
plt.ylabel('RMSE')
plt.title('Prediction Error by Sensor Location')
plt.xticks(rotation=45, ha='right')
#plt.tight_layout()
plt.show()
# Out:
# Visualizing model predictions vs actual values...

# %%
plt.figure(figsize=(12, 8))
#for i, sensor in enumerate(AD.air_sens_loc.keys()):
for i, sensor in enumerate(air_sensor_loc):
    plt.subplot(3, 2, i + 1)
    plt.plot(y_test[:, i], label='Actual', marker='o')
    plt.plot(y_pred[:, i], label='Predicted', marker='x')
    plt.title(f'Sensor: {sensor}')
    plt.xlabel('Time Step')
    plt.ylabel('PM2.5')
    plt.legend()
    plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# left shift preds by 1
plt.figure(figsize=(12, 8))
#for i, sensor in enumerate(AD.air_sens_loc.keys()):
for i, sensor in enumerate(air_sensor_loc):
    plt.subplot(3, 2, i + 1)
    plt.plot(y_test[:, i], label='Actual', marker='o')
    plt.plot(y_pred[1:, i], label='Predicted, left shift by 1', marker='x')
    plt.title(f'Sensor: {sensor}')
    plt.xlabel('Time Step')
    plt.ylabel('PM2.5')
    plt.legend()
    plt.grid(True)
plt.tight_layout()
plt.show()
